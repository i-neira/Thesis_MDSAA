# %% [markdown]
# ### Import needed libraries

# %%
# File and system utilities
import os
import sys
from pathlib import Path
import json  # Handle JSON files

#  Data Modeling and Typing
from typing import Optional, List, Dict, Any
from pydantic import BaseModel

#  LangChain
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.runnables import RunnableLambda
from langchain.chains import create_extraction_chain, create_extraction_chain_pydantic
# from langchain.chains import create_extraction_chain_pydantic
from langchain.output_parsers.openai_tools import JsonOutputToolsParser
from langchain import hub  # Access shared LangChain assets

#  Azure / OpenAI Integration
from langchain_openai.chat_models import AzureChatOpenAI

# Local functions
from AI_chunker_v2 import AgenticChunker, create_agentic_chunker

# AI_chunker_v2 was adapted from https://github.com/FullStackRetrieval-com/RetrievalTutorials/blob/a4570f3c4883eb9b835b0ee18990e62298f518ef/tutorials/LevelsOfTextSplitting/agentic_chunker.py

# %%
## Paths in the project

# Base Folder:
base_folder = os.path.dirname(os.getcwd())

# Answers path
answers_path = os.path.join(base_folder, 'Answers')

# Vector_DBs path
vector_dbs_path = os.path.join(base_folder, 'Vector_DBs')

# Code path
code_path = os.path.join(base_folder, 'Code')

# AI_Prepositions path
ai_prepositions_path = os.path.join(base_folder, 'AI_Prepositions')

# Corpus path
corpus_path = os.path.join(base_folder, 'Corpus')

# Ground_Truth path
ground_truth_path = os.path.join(base_folder, 'Ground_Truth')

# RAGAS_Results path
ragas_results_path = os.path.join(base_folder, 'RAGAS_Results')

# %% [markdown]
# ### Setup Azure API

# %%
########## Setup the Azure API

os.environ["AZURE_OPENAI_API_KEY"] = "YOUR_KEY" # Your Key

azure_configs = {
    "base_url": "YOUR_URL", # Your endpoint
    "model_deployment": "YOUR_MODEL", # Your model_deployment (LLM)
    "model_name": "YOUR_MODEL_NAME" # Your model_name (LLM)
}

# %%
# Initialize the LLM (gpt-4o) for the chunk process
llm = AzureChatOpenAI(
    openai_api_version="YOUR API_version", # Your API_version
    azure_endpoint=azure_configs["base_url"],
    azure_deployment=azure_configs["model_deployment"],
    model=azure_configs["model_name"],
    validate_base_url=False,
)

# %% [markdown]
# ### Prepare prompt and .txt files

# %%
# Prompt to split texts
prompt_template = """
You are a proposition extractor. Your task is to break down the provided "Content" into a list of clear, standalone, and context-independent propositions. Each proposition must convey a single, interpretable idea that can be understood without referencing surrounding text.

Follow these detailed instructions:

1. Split complex or compound sentences into multiple simple propositions. Each proposition should express a single atomic fact or claim.
2. Preserve the original wording as much as possible. Avoid paraphrasing unless necessary to improve clarity.
3. Separate descriptive information about entities into distinct propositions. For example, if a person is identified with a profession or title, extract that information into its own proposition.
4. Resolve all pronouns and ambiguous references. Replace them with the full name or noun phrase they refer to.
5. Add minimal necessary context to decontextualize each proposition. Include names, dates, or locations when needed to make the statement understandable in isolation.
6. Output the propositions as a JSON array of strings. Each item in the array should be one proposition.

Content to analyze:
{content}

Please extract the propositions and return them as a JSON array:
"""

# %%
prompt = ChatPromptTemplate.from_template(prompt_template)

# Create the runnable chain
runnable = prompt | llm

# %%
# List to save the documents
documents = []

# Check all the .txt files in the folder
for filename in os.listdir(corpus_path):
    if filename.endswith(".txt"):
        file_path = os.path.join(corpus_path, filename)
        with open(file_path, "r", encoding="utf-8") as file:
            content = file.read()
            documents.append({
                "filename": filename,
                "content": content
            })

print(f"{len(documents)} documents have been uploaded.")
# Out:
# 52 documents have been uploaded.

# %% [markdown]
# ### Get propositions from each document + useful functions

# %%
## PROCESSING AND PROPOSITION EXTRACTION

def extract_propositions_from_text(content):
    """
    Extract propositions from text using the LLM
    """
    try:
        # Invoke the LLM with the content
        response = runnable.invoke({"content": content})
        
        # Get the response content
        response_content = response.content
        
        # Try to parse the JSON response
        try:
            # Look for JSON array in the response
            start_idx = response_content.find('[')
            end_idx = response_content.rfind(']') + 1
            
            if start_idx != -1 and end_idx != 0:
                json_str = response_content[start_idx:end_idx]
                propositions = json.loads(json_str)
                return propositions
            else:
                print("A valid JSON array was not found in the response")
                return []
                
        except json.JSONDecodeError as e:
            print(f"Error parsing JSON: {e}")
            print(f"LLM response: {response_content}")
            return []
            
    except Exception as e:
        print(f"Error in text processing: {e}")
        return []

# Process each document and extract propositions
processed_documents = []

for i, doc in enumerate(documents[2:52]):
    print(f"\n Processing document {i+1}/{len(documents)}: {doc['filename']}")
    
    # Extract propositions from the document content
    propositions = extract_propositions_from_text(doc['content'])
    
    # Store the processed document with propositions
    processed_doc = {
        "filename": doc['filename'],
        "original_content": doc['content'],
        "propositions": propositions,
        "num_propositions": len(propositions)
    }
    
    processed_documents.append(processed_doc)
    
    print(f" Retrieved  {len(propositions)} propositions from {doc['filename']}")
# Out:
#  Processing document 1/52: 03. NISS Registration.txt
#  Retrieved  52 propositions from 03. NISS Registration.txt
#
#  Processing document 2/52: 04. NOVA's master's programs.txt
#  Retrieved  42 propositions from 04. NOVA's master's programs.txt
#
#  Processing document 3/52: 05. NOVA's bachelor  programs.txt
#  Retrieved  4 propositions from 05. NOVA's bachelor  programs.txt
#
#  Processing document 4/52: 06. NOVA's FAQ.txt
#  Retrieved  82 propositions from 06. NOVA's FAQ.txt
#
#  Processing document 5/52: 07. AIMA Residence Permit Issued to Higher Education Students – Article 91.txt
#  Retrieved  47 propositions from 07. AIMA Residence Permit Issued to Higher Education Students – Article 91.txt
#
#  Processing document 6/52: 08. AIMA - Means of Subsistence.txt
#  Retrieved  36 propositions from 08. AIMA - Means of Subsistence.txt
#
#  Processing document 7/52: 09. VISA.txt
#  Retrieved  41 propositions from 09. VISA.txt
#
#  Processing document 8/52: Bachelor's_Degree_in_Data_Science.txt
#  Retrieved  55 propositions from Bachelor's_Degree_in_Data_Science.txt
#
#  Processing document 9/52: Bachelor's_Degree_in_Information_Management.txt
#  Retrieved  58 propositions from Bachelor's_Degree_in_Information_Management.txt
#
#  Processing document 10/52: Bachelor's_Degree_in_Information_Systems.txt
#  Retrieved  81 propositions from Bachelor's_Degree_in_Information_Systems.txt
#
#  Processing document 11/52: European_Master_of_Science_in_Information_Systems_Management.txt
#  Retrieved  57 propositions from European_Master_of_Science_in_Information_Systems_Management.txt
#
#  Processing document 12/52: Master_Degree_in_Clinical_Research_Management.txt
#  Retrieved  28 propositions from Master_Degree_in_Clinical_Research_Management.txt
#
#  Processing document 13/52: Master_Degree_in_Data-Driven_Marketing,_with_a_specialization_in_Data_Science_for_Marketing.txt
#  Retrieved  30 propositions from Master_Degree_in_Data-Driven_Marketing,_with_a_specialization_in_Data_Science_for_Marketing.txt
#
#  Processing document 14/52: Master_Degree_in_Data-Driven_Marketing,_with_a_specialization_in_Digital_Marketing_and_Analytics.txt
#  Retrieved  13 propositions from Master_Degree_in_Data-Driven_Marketing,_with_a_specialization_in_Digital_Marketing_and_Analytics.txt
#
#  Processing document 15/52: Master_Degree_in_Data-Driven_Marketing,_with_a_specialization_in_Marketing_Intelligence.txt
#  Retrieved  13 propositions from Master_Degree_in_Data-Driven_Marketing,_with_a_specialization_in_Marketing_Intelligence.txt
#
#  Processing document 16/52: Master_Degree_in_Data-Driven_Marketing,_with_a_specialization_in_Marketing_Research_and_CRM.txt
#  Retrieved  67 propositions from Master_Degree_in_Data-Driven_Marketing,_with_a_specialization_in_Marketing_Research_and_CRM.txt
#
#  Processing document 17/52: Master_Degree_in_Data_Science_and_Advanced_Analytics,_with_a_specialization_in_Business_Analytics.txt
#  Retrieved  73 propositions from Master_Degree_in_Data_Science_and_Advanced_Analytics,_with_a_specialization_in_Business_Analytics.txt
#
#  Processing document 18/52: Master_Degree_in_Data_Science_and_Advanced_Analytics,_with_a_specialization_in_Data_Science.txt
#  Retrieved  72 propositions from Master_Degree_in_Data_Science_and_Advanced_Analytics,_with_a_specialization_in_Data_Science.txt
#
#  Processing document 19/52: Master_Degree_in_Geographic_Information_Systems_and_Science,_with_a_specialization_in_Geographic_Information_Systems_and_Science.txt
#  Retrieved  80 propositions from Master_Degree_in_Geographic_Information_Systems_and_Science,_with_a_specialization_in_Geographic_Information_Systems_and_Science.txt
#
#  Processing document 20/52: Master_Degree_in_Geographic_Information_Systems_and_Science,_with_a_specialization_in_Geospatial_Data_Science.txt
#  Retrieved  78 propositions from Master_Degree_in_Geographic_Information_Systems_and_Science,_with_a_specialization_in_Geospatial_Data_Science.txt
#
#  Processing document 21/52: Master_Degree_in_Information_Management,_with_a_specialization_in_Business_Intelligence.txt
#  Retrieved  14 propositions from Master_Degree_in_Information_Management,_with_a_specialization_in_Business_Intelligence.txt
#
#  Processing document 22/52: Master_Degree_in_Information_Management,_with_a_specialization_in_Digital_Transformation.txt
#  Retrieved  78 propositions from Master_Degree_in_Information_Management,_with_a_specialization_in_Digital_Transformation.txt
#
#  Processing document 23/52: Master_Degree_in_Information_Management,_with_a_specialization_in_Information_Systems_Management.txt
#  Retrieved  14 propositions from Master_Degree_in_Information_Management,_with_a_specialization_in_Information_Systems_Management.txt
#
#  Processing document 24/52: Master_Degree_in_Law_and_Financial_Markets.txt
#  Retrieved  62 propositions from Master_Degree_in_Law_and_Financial_Markets.txt
#
#  Processing document 25/52: Master_Degree_in_Risk_Management.txt
#  Retrieved  68 propositions from Master_Degree_in_Risk_Management.txt
#
#  Processing document 26/52: Master_Degree_in_Statistics_and_Information_Management,_with_a_specialization_in_Data_Analytics.txt
#  Retrieved  77 propositions from Master_Degree_in_Statistics_and_Information_Management,_with_a_specialization_in_Data_Analytics.txt
#
#  Processing document 27/52: Master_of_Science_in_Geospatial_Technologies.txt
#  Retrieved  48 propositions from Master_of_Science_in_Geospatial_Technologies.txt
#
#  Processing document 28/52: Postgraduate_Program_Enterprise_Data_Science_&_Analytics.txt
#  Retrieved  66 propositions from Postgraduate_Program_Enterprise_Data_Science_&_Analytics.txt
#
#  Processing document 29/52: Postgraduate_Program_in_Artificial_Intelligence_for_Business_Transformation.txt
#  Retrieved  80 propositions from Postgraduate_Program_in_Artificial_Intelligence_for_Business_Transformation.txt
#
#  Processing document 30/52: Postgraduate_Program_in_Business_Intelligence.txt
#  Retrieved  84 propositions from Postgraduate_Program_in_Business_Intelligence.txt
#
#  Processing document 31/52: Postgraduate_Program_in_Business_Intelligence_and_Analytics_for_Hospitality_&_Tourism.txt
#  Retrieved  62 propositions from Postgraduate_Program_in_Business_Intelligence_and_Analytics_for_Hospitality_&_Tourism.txt
#
#  Processing document 32/52: Postgraduate_Program_in_Data_Analytics.txt
#  Retrieved  62 propositions from Postgraduate_Program_in_Data_Analytics.txt
#
#  Processing document 33/52: Postgraduate_Program_in_Data_Science_for_Finance.txt
#  Retrieved  108 propositions from Postgraduate_Program_in_Data_Science_for_Finance.txt
#
#  Processing document 34/52: Postgraduate_Program_in_Data_Science_for_Marketing.txt
#  Retrieved  75 propositions from Postgraduate_Program_in_Data_Science_for_Marketing.txt
#
#  Processing document 35/52: Postgraduate_Program_in_Digital_Marketing_and_Analytics.txt
#  Retrieved  56 propositions from Postgraduate_Program_in_Digital_Marketing_and_Analytics.txt
#
#  Processing document 36/52: Postgraduate_Program_in_Digital_Transformation.txt
#  Retrieved  59 propositions from Postgraduate_Program_in_Digital_Transformation.txt
#
#  Processing document 37/52: Postgraduate_Program_in_Financial_and_Budgetary_Management_and_Control.txt
#  Retrieved  73 propositions from Postgraduate_Program_in_Financial_and_Budgetary_Management_and_Control.txt
#
#  Processing document 38/52: Postgraduate_Program_in_Financial_Markets_and_Risks.txt
#  Retrieved  73 propositions from Postgraduate_Program_in_Financial_Markets_and_Risks.txt
#
#  Processing document 39/52: Postgraduate_Program_in_Geographic_Information_Systems_and_Science.txt
#  Retrieved  70 propositions from Postgraduate_Program_in_Geographic_Information_Systems_and_Science.txt
#
#  Processing document 40/52: Postgraduate_Program_in_Geospatial_Data_Science.txt
#  Retrieved  85 propositions from Postgraduate_Program_in_Geospatial_Data_Science.txt
#
#  Processing document 41/52: Postgraduate_Program_in_Geospatial_Intelligence.txt
#  Retrieved  71 propositions from Postgraduate_Program_in_Geospatial_Intelligence.txt
#
#  Processing document 42/52: Postgraduate_Program_in_Health_Data_Science_and_Analytics.txt
#  Retrieved  79 propositions from Postgraduate_Program_in_Health_Data_Science_and_Analytics.txt
#
#  Processing document 43/52: Postgraduate_Program_in_Information_Management_and_Business_Intelligence_in_Healthcare.txt
#  Retrieved  71 propositions from Postgraduate_Program_in_Information_Management_and_Business_Intelligence_in_Healthcare.txt
#
#  Processing document 44/52: Postgraduate_Program_in_Information_Systems_Management.txt
#  Retrieved  59 propositions from Postgraduate_Program_in_Information_Systems_Management.txt
#
#  Processing document 45/52: Postgraduate_Program_in_Intelligence_Management_and_Security.txt
#  Retrieved  70 propositions from Postgraduate_Program_in_Intelligence_Management_and_Security.txt
#
#  Processing document 46/52: Postgraduate_Program_in_Marketing_Intelligence.txt
#  Retrieved  62 propositions from Postgraduate_Program_in_Marketing_Intelligence.txt
#
#  Processing document 47/52: Postgraduate_Program_in_Marketing_Research_and_CRM.txt
#  Retrieved  56 propositions from Postgraduate_Program_in_Marketing_Research_and_CRM.txt
#
#  Processing document 48/52: Postgraduate_Program_in_Risk_Management.txt
#  Retrieved  63 propositions from Postgraduate_Program_in_Risk_Management.txt
#
#  Processing document 49/52: Postgraduate_Program_in_Statistical_Systems,_with_a_specialization_in_Central_Banks'_Statistics.txt
#  Retrieved  70 propositions from Postgraduate_Program_in_Statistical_Systems,_with_a_specialization_in_Central_Banks'_Statistics.txt
#
#  Processing document 50/52: Postgraduate_Program_in_Statistical_Systems,_with_a_specialization_in_Official_Statistics.txt
#  Retrieved  61 propositions from Postgraduate_Program_in_Statistical_Systems,_with_a_specialization_in_Official_Statistics.txt

# %%
## RESULTS SUMMARY

total_propositions = 0
for doc in processed_documents:
    print(f"\n📄 {doc['filename']}:")
    print(f"   - Retrieved propositions: {doc['num_propositions']}")
    total_propositions += doc['num_propositions']
    
    # Show first 3 propositions as example
    if doc['propositions']:
        print("   - First propositions:")
        for j, prop in enumerate(doc['propositions'][:3]):
            print(f"     {j+1}. {prop}")
        if len(doc['propositions']) > 3:
            print(f"     ... and {len(doc['propositions']) - 3} more")

print(f"\n Total number of proposals retrieved: {total_propositions}")
# Out:
# 📄 03. NISS Registration.txt:
#    - Retrieved propositions: 52
#    - First propositions:
#      1. The Social Security Identification Number (NISS) allows unique, precise, and accurate identification of citizens in the Social Security system at the national level.
#      2. The Social Security Identification Number (NISS) is automatically allocated to national citizens when they apply for the Citizen Card.
#      3. Foreign citizens and national citizens who are not required to have a Citizen Card must submit a request for a Social Security Identification Number (NISS).
#      ... and 49 more
#
# 📄 04. NOVA's master's programs.txt:
#    - Retrieved propositions: 42
#    - First propositions:
#      1. NOVA IMS offers 23 postgraduate programs.
#      2. NOVA IMS offers 17 master's programs.
#      3. NOVA IMS offers a Postgraduate Program in Artificial Intelligence for Business Transformation.
#      ... and 39 more
#
# 📄 05. NOVA's bachelor  programs.txt:
#    - Retrieved propositions: 4
#    - First propositions:
#      1. NOVA IMS offers three bachelor's degree programs.
#      2. NOVA IMS offers a bachelor's degree program in Data Science.
#      3. NOVA IMS offers a bachelor's degree program in Information Management.
#      ... and 1 more
#
# 📄 06. NOVA's FAQ.txt:
#    - Retrieved propositions: 82
#    - First propositions:
#      1. Frequently asked questions can be explored to find answers.
#      2. If you have unanswered questions, you can contact NOVA IMS.
#      3. It is only possible to submit applications during the applications phase.
#      ... and 79 more
#
# 📄 07. AIMA Residence Permit Issued to Higher Education Students – Article 91.txt:
#    - Retrieved propositions: 47
#    - First propositions:
#      1. Law no. 23/2007, of July 4, approves the legal regime for the entry, stay, exit, and removal of foreigners from Portuguese national territory.
#      2. Article 91 of Law no. 23/2007, in conjunction with Article 57 of Regulatory Decree no. 84/07 of November 5, establishes the framework for issuing residence permits to higher education students.
#      3. A residence permit is granted to higher education students holding a residence visa issued under Article 62 of REPSAE.
#      ... and 44 more
#
# 📄 08. AIMA - Means of Subsistence.txt:
#    - Retrieved propositions: 36
#    - First propositions:
#      1. Ordinance no. 1563/2007, of December 11, establishes the means of subsistence that third-country nationals must have for entry and stay in Portugal.
#      2. The reference value for the means of subsistence is the guaranteed monthly minimum wage, that is, the national minimum wage.
#      3. According to Decree-Law no. 107/2023, of November 17, the minimum wage set for 2024 is €820.
#      ... and 33 more
#
# 📄 09. VISA.txt:
#    - Retrieved propositions: 41
#    - First propositions:
#      1. A National Visa application must be filled and duly signed by the applicant.
#      2. For minors and incapacitated individuals, forms must be signed by the legal guardian.
#      3. Two passport-type photos are required, even, recent, and in good condition to identify the applicant.
#      ... and 38 more
#
# 📄 Bachelor's_Degree_in_Data_Science.txt:
#    - Retrieved propositions: 55
#    - First propositions:
#      1. Students enrolled in the Bachelor's Degree in Data Science learn the most modern artificial intelligence and machine learning techniques to analyze large volumes of data (Big Data).
#      2. Graduates of the Bachelor's Degree in Data Science will become data scientists.
#      3. The profession of data scientist is considered the sexiest profession of the 21st century by the Harvard Business Review.
#      ... and 52 more
#
# 📄 Bachelor's_Degree_in_Information_Management.txt:
#    - Retrieved propositions: 58
#    - First propositions:
#      1. The Bachelor’s degree in Information Management combines management with data science.
#      2. The Bachelor’s degree in Information Management prepares students to be managers of the new generation.
#      3. The managers of the new generation are capable of understanding business and the current challenges of modern management.
#      ... and 55 more
#
# 📄 Bachelor's_Degree_in_Information_Systems.txt:
#    - Retrieved propositions: 81
#    - First propositions:
#      1. In the 2025/26 academic year, the 4th phase of applications under the International Student Statute will be open from April 24th to May 28th, 2025.
#      2. Information Technologies are present in diverse areas of knowledge and people's everyday lives, even when they do not realize it.
#      3. People permanently use intelligent systems, connectivity services, network equipment, and data integration.
#      ... and 78 more
#
# 📄 European_Master_of_Science_in_Information_Systems_Management.txt:
#    - Retrieved propositions: 57
#    - First propositions:
#      1. The European Master of Science in Information Systems Management is aimed at graduates who want to acquire additional information systems management skills for their professional field.
#      2. Graduates of the program intend to receive a master's double degree diploma from two universities.
#      3. One of the diplomas is an M.Sc. in Information Management, with a specialization in Information Systems Management, from NOVA Information Management School of Universidade NOVA de Lisboa in Portugal.
#      ... and 54 more
#
# 📄 Master_Degree_in_Clinical_Research_Management.txt:
#    - Retrieved propositions: 28
#    - First propositions:
#      1. The Master Degree Program in Clinical Research Management is developed in partnership with NOVA IMS, NOVA Medical School (NMS|FCM), National School of Public Health (ENSP-NOVA), and Universidade de Aveiro (UA).
#      2. The Master Degree Program in Clinical Research Management aims to train highly qualified human resources to enable clinical research in health care facilities, universities, academic centers, biobanks, pharmaceutical and healthcare technology companies, and clinical research organizations.
#      3. The training and professionalization of structures and teams that support clinical research improve the quality of research teams.
#      ... and 25 more
#
# 📄 Master_Degree_in_Data-Driven_Marketing,_with_a_specialization_in_Data_Science_for_Marketing.txt:
#    - Retrieved propositions: 30
#    - First propositions:
#      1. The Master Degree Program is called Master Degree in Data-Driven Marketing.
#      2. The Master Degree in Data-Driven Marketing includes a specialization in Data Science for Marketing.
#      3. The Master Degree Program in Data-Driven Marketing aims to fill a gap in the postgraduate training of marketing professionals.
#      ... and 27 more
#
# 📄 Master_Degree_in_Data-Driven_Marketing,_with_a_specialization_in_Digital_Marketing_and_Analytics.txt:
#    - Retrieved propositions: 13
#    - First propositions:
#      1. The Master's Degree Program in Data-Driven Marketing has a specialization in Digital Marketing and Analytics.
#      2. The Master's Degree Program in Data-Driven Marketing is aimed at managers, experts, and other professionals.
#      3. The Master's Degree Program in Data-Driven Marketing helps professionals obtain skills in Digital Marketing and Web Analytics.
#      ... and 10 more
#
# 📄 Master_Degree_in_Data-Driven_Marketing,_with_a_specialization_in_Marketing_Intelligence.txt:
#    - Retrieved propositions: 13
#    - First propositions:
#      1. The Master Degree in Data-Driven Marketing specializes in Marketing Intelligence.
#      2. The Master Degree Program in Data-Driven Marketing trains technical and management staff.
#      3. The program trains staff to lead the collection of marketing information in organizations.
#      ... and 10 more
#
# 📄 Master_Degree_in_Data-Driven_Marketing,_with_a_specialization_in_Marketing_Research_and_CRM.txt:
#    - Retrieved propositions: 67
#    - First propositions:
#      1. The Master Degree in Data-Driven Marketing specializes in Marketing Research and CRM.
#      2. The Master Degree Program in Data-Driven Marketing fills a gap in the high-level training of managers, technical staff, and other experts in marketing.
#      3. The Master Degree Program is targeted at technical staff and market researchers.
#      ... and 64 more
#
# 📄 Master_Degree_in_Data_Science_and_Advanced_Analytics,_with_a_specialization_in_Business_Analytics.txt:
#    - Retrieved propositions: 73
#    - First propositions:
#      1. The Master degree Program in Data Science and Advanced Analytics specializes in Business Analytics.
#      2. The Master degree Program is aimed at market-oriented people.
#      3. The program focuses on applying effective analytical models to different business problems.
#      ... and 70 more
#
# 📄 Master_Degree_in_Data_Science_and_Advanced_Analytics,_with_a_specialization_in_Data_Science.txt:
#    - Retrieved propositions: 72
#    - First propositions:
#      1. The Master Degree Program in Data Science and Advanced Analytics specializes in Data Science.
#      2. The program is aimed at technically oriented people with a solid scientific background.
#      3. The program is designed for individuals who want to strengthen and deepen their skills in commonly used paradigms and environments for software development.
#      ... and 69 more
#
# 📄 Master_Degree_in_Geographic_Information_Systems_and_Science,_with_a_specialization_in_Geographic_Information_Systems_and_Science.txt:
#    - Retrieved propositions: 80
#    - First propositions:
#      1. The program is a Master's Degree in Geographic Information Systems and Science.
#      2. The program has a specialization in Geographic Information Systems and Science.
#      3. The specialization provides a technical and scientific framework related to the use of geographic information technology and analysis.
#      ... and 77 more
#
# 📄 Master_Degree_in_Geographic_Information_Systems_and_Science,_with_a_specialization_in_Geospatial_Data_Science.txt:
#    - Retrieved propositions: 78
#    - First propositions:
#      1. A Master's Degree is offered in Geographic Information Systems and Science.
#      2. The Master's Degree program has a specialization in Geospatial Data Science.
#      3. The specialization in Geospatial Data Science provides skills for the analysis, modeling, and visualization of geographic information.
#      ... and 75 more
#
# 📄 Master_Degree_in_Information_Management,_with_a_specialization_in_Business_Intelligence.txt:
#    - Retrieved propositions: 14
#    - First propositions:
#      1. Master Degree in Information Management has a specialization in Business Intelligence.
#      2. The Master Degree Program in Information Management aims to train experts and managers able to design, build, and use business intelligence processes.
#      3. The Master Degree Program in Information Management aims to train experts and managers able to design, build, and use analytics processes.
#      ... and 11 more
#
# 📄 Master_Degree_in_Information_Management,_with_a_specialization_in_Digital_Transformation.txt:
#    - Retrieved propositions: 78
#    - First propositions:
#      1. The program is a Master Degree in Information Management with a specialization in Digital Transformation.
#      2. The Master Degree in Information Management focuses on digital transformation in business.
#      3. The program recognizes the significance of digital transformation in today's business world.
#      ... and 75 more
#
# 📄 Master_Degree_in_Information_Management,_with_a_specialization_in_Information_Systems_Management.txt:
#    - Retrieved propositions: 14
#    - First propositions:
#      1. The Master Degree Program in Information Management includes a specialization in Information Systems Management.
#      2. The Master Degree Program in Information Management is aimed at professionals who have roles in Information Systems.
#      3. The professionals targeted by the program include managers and experts in the coordination of Information Systems projects.
#      ... and 11 more
#
# 📄 Master_Degree_in_Law_and_Financial_Markets.txt:
#    - Retrieved propositions: 62
#    - First propositions:
#      1. The Master Degree in Law and Financial Markets is offered in partnership by NOVA Information Management School and NOVA School of Law.
#      2. The Master Degree in Law and Financial Markets is fully taught in English.
#      3. The Master Degree in Law and Financial Markets is consistently ranked by Eduniversal among the top master's courses in Western Europe.
#      ... and 59 more
#
# 📄 Master_Degree_in_Risk_Management.txt:
#    - Retrieved propositions: 68
#    - First propositions:
#      1. The Master's Degree Program in Risk Management prepares professionals and executives to address challenges of identifying, assessing, and managing risk in the financial sector.
#      2. The program aligns with international standards such as those set by the CFA Institute and GARP.
#      3. The program covers essential knowledge needed for informed decision-making.
#      ... and 65 more
#
# 📄 Master_Degree_in_Statistics_and_Information_Management,_with_a_specialization_in_Data_Analytics.txt:
#    - Retrieved propositions: 77
#    - First propositions:
#      1. The program is a Master's Degree in Statistics and Information Management, with a specialization in Data Analytics.
#      2. The Master's Degree Program aims to train experts and managers qualified to lead and guide information collection, compilation, analysis, and management inside organizations.
#      3. Experts and managers with skills in information collection and analysis are scarce in today's data-driven landscape.
#      ... and 74 more
#
# 📄 Master_of_Science_in_Geospatial_Technologies.txt:
#    - Retrieved propositions: 48
#    - First propositions:
#      1. The Master's of Science in Geospatial Technologies (Erasmus Mundus Program) is a cooperation between NOVA IMS in Portugal, the Institute for Geoinformatics (IFGI) of the University of Münster (WWU) in Germany, and the Universitat Jaume I (UJI) in Spain.
#      2. The Master's of Science in Geospatial Technologies is aimed at graduates who wish to obtain qualifications in fields where geographic information is applied.
#      3. The Master's of Science in Geospatial Technologies is aimed at graduates who intend to have a multicultural experience.
#      ... and 45 more
#
# 📄 Postgraduate_Program_Enterprise_Data_Science_&_Analytics.txt:
#    - Retrieved propositions: 66
#    - First propositions:
#      1. The Postgraduate Program in Enterprise Data Science & Analytics is developed in partnership with Microsoft.
#      2. The Postgraduate Program in Enterprise Data Science & Analytics presents methodologies and tools for transforming data into information.
#      3. Enterprises can base strategic decisions on information transformed from data.
#      ... and 63 more
#
# 📄 Postgraduate_Program_in_Artificial_Intelligence_for_Business_Transformation.txt:
#    - Retrieved propositions: 80
#    - First propositions:
#      1. The Postgraduate Program in Artificial Intelligence for Business Transformation equips managers and professionals to lead digital transformation.
#      2. The Postgraduate Program in Artificial Intelligence for Business Transformation enables mastery of artificial intelligence, machine learning, big data & analytics, IoT, and other disruptive technologies.
#      3. Innovation redefines competitiveness in the current business landscape.
#      ... and 77 more
#
# 📄 Postgraduate_Program_in_Business_Intelligence.txt:
#    - Retrieved propositions: 84
#    - First propositions:
#      1. Businesses operate in a globalizing and ever-changing environment.
#      2. The ability to leverage data and digital transformation is a critical success factor for businesses.
#      3. Data and digital transformation help manage information and knowledge in organizations.
#      ... and 81 more
#
# 📄 Postgraduate_Program_in_Business_Intelligence_and_Analytics_for_Hospitality_&_Tourism.txt:
#    - Retrieved propositions: 62
#    - First propositions:
#      1. The Postgraduate Program in Business Intelligence and Analytics for Hospitality & Tourism responds to the need for higher education in the tourism industry.
#      2. Tourism is fundamental to the development of the world economy.
#      3. The program aims to prepare professionals capable of developing and applying analytical models for tourism and hospitality.
#      ... and 59 more
#
# 📄 Postgraduate_Program_in_Data_Analytics.txt:
#    - Retrieved propositions: 62
#    - First propositions:
#      1. The Postgraduate Program in Data Analytics aims to train experts and managers qualified to lead and guide information collection, compilation, analysis, and management inside organizations.
#      2. Experts and managers with skills in information collection, compilation, analysis, and management are highly scarce in today's data-driven landscape.
#      3. Organizations crave professionals who can navigate the vast seas of information and transform raw data into actionable insights.
#      ... and 59 more
#
# 📄 Postgraduate_Program_in_Data_Science_for_Finance.txt:
#    - Retrieved propositions: 108
#    - First propositions:
#      1. The Postgraduate Diploma in Data Science for Finance is an internationally innovative training program.
#      2. The program offers a quantitative and analytical approach to finance.
#      3. The program is aimed at professionals in the financial sector seeking a more analytical approach to finance.
#      ... and 105 more
#
# 📄 Postgraduate_Program_in_Data_Science_for_Marketing.txt:
#    - Retrieved propositions: 75
#    - First propositions:
#      1. The Postgraduate program in Data Science for Marketing aims to fill a gap in the postgraduate training of marketing professionals.
#      2. Marketing professionals need to gain new skills to actively participate in the development and application of analytical marketing models.
#      3. The study plan of the Postgraduate program in Data Science for Marketing presents an up-to-date structure.
#      ... and 72 more
#
# 📄 Postgraduate_Program_in_Digital_Marketing_and_Analytics.txt:
#    - Retrieved propositions: 56
#    - First propositions:
#      1. The digital revolution has changed the way people search for information.
#      2. The digital revolution has changed the way people consume content.
#      3. The digital revolution has changed the way people interact.
#      ... and 53 more
#
# 📄 Postgraduate_Program_in_Digital_Transformation.txt:
#    - Retrieved propositions: 59
#    - First propositions:
#      1. The Postgraduate Program in Digital Transformation recognizes the significance of digital transformation in today's business world.
#      2. The Postgraduate Program in Digital Transformation aims to strengthen NOVA IMS's training offering in the area of digital transformation.
#      3. The program focuses on exploring technological advancements and processes to help organizations enhance their competitive advantage.
#      ... and 56 more
#
# 📄 Postgraduate_Program_in_Financial_and_Budgetary_Management_and_Control.txt:
#    - Retrieved propositions: 73
#    - First propositions:
#      1. The Postgraduate Program in Financial and Budgetary Management and Control was developed in partnership with the Inspectorate General of Finance – Portuguese Audit Authority (IGF).
#      2. The Postgraduate Program in Financial and Budgetary Management and Control aims to empower participants with competencies in management and financial control.
#      3. These competencies enable the development of new information management strategies relevant to the performance of functions in the financial and budgetary sphere.
#      ... and 70 more
#
# 📄 Postgraduate_Program_in_Financial_Markets_and_Risks.txt:
#    - Retrieved propositions: 73
#    - First propositions:
#      1. The Postgraduate Program in Financial Markets and Risks is offered through a partnership between NOVA Information Management School and ISCTE Executive Education.
#      2. The program combines a prestigious teaching staff that aligns knowledge and scientific rigor with practical experience.
#      3. The program includes current and innovative contents with a strong applied component.
#      ... and 70 more
#
# 📄 Postgraduate_Program_in_Geographic_Information_Systems_and_Science.txt:
#    - Retrieved propositions: 70
#    - First propositions:
#      1. The Postgraduate Program in Geographic Information Systems and Science provides a technical and scientific framework related to the use of geographic information technology and analysis.
#      2. The Postgraduate Program in Geographic Information Systems and Science provides skills related to the modeling and analysis of spatial data.
#      3. The Postgraduate Program in Geographic Information Systems and Science provides skills related to the design and planning of geographic information technology and analysis in organizations.
#      ... and 67 more
#
# 📄 Postgraduate_Program_in_Geospatial_Data_Science.txt:
#    - Retrieved propositions: 85
#    - First propositions:
#      1. The Postgraduate Program in Geospatial Data Science provides the necessary skills for the analysis, modeling, and visualization of geographic information.
#      2. The Postgraduate Program in Geospatial Data Science aims to train professionals for the role of artificial intelligence, programming, and data mining.
#      3. Artificial intelligence, programming, and data mining can be used to develop solutions to challenges and societal problems in the public and private sectors.
#      ... and 82 more
#
# 📄 Postgraduate_Program_in_Geospatial_Intelligence.txt:
#    - Retrieved propositions: 71
#    - First propositions:
#      1. The Geospatial Intelligence Certificate is accredited by the United States Geospatial Intelligence Foundation (USGIF).
#      2. The Geospatial Intelligence Certificate provides education and training in scientific concepts, methods, and key geospatial technologies.
#      3. Key geospatial technologies are used in the solution of global problems of security and defense.
#      ... and 68 more
#
# 📄 Postgraduate_Program_in_Health_Data_Science_and_Analytics.txt:
#    - Retrieved propositions: 79
#    - First propositions:
#      1. The Postgraduate Program in Health Data Science and Analytics is specifically designed for healthcare professionals.
#      2. The program aims to help healthcare professionals acquire advanced skills in managing health sciences data.
#      3. The program helps students interpret health sciences data.
#      ... and 76 more
#
# 📄 Postgraduate_Program_in_Information_Management_and_Business_Intelligence_in_Healthcare.txt:
#    - Retrieved propositions: 71
#    - First propositions:
#      1. The Postgraduate Program in Information Management and Business Intelligence in Healthcare aims to train managers and healthcare professionals.
#      2. The program is intended for those who wish to use information and knowledge management to promote the competitiveness of healthcare organizations.
#      3. The program covers a wide range of topics, including health policy, strategy, information systems, and data science.
#      ... and 68 more
#
# 📄 Postgraduate_Program_in_Information_Systems_Management.txt:
#    - Retrieved propositions: 59
#    - First propositions:
#      1. The Postgraduate Program in Information Systems Management explores various technologies in IT and their impact on planning, design, functionality, and information systems management.
#      2. The Postgraduate Program in Information Systems Management focuses on understanding the interaction between technology and business processes, strategy, and organizational policies.
#      3. The Postgraduate Program in Information Systems Management promotes strategic thinking regarding the role of information systems in developing management strategies.
#      ... and 56 more
#
# 📄 Postgraduate_Program_in_Intelligence_Management_and_Security.txt:
#    - Retrieved propositions: 70
#    - First propositions:
#      1. The Postgraduate Program in Intelligence Management and Security develops skills to understand and address challenges in security, defense, international cooperation, and information culture.
#      2. The program provides analytical competencies and methodologies to assess, manage, and make decisions in complex international security and defense contexts.
#      3. International security and defense contexts require an understanding of political, diplomatic, economic, social, and regional frameworks.
#      ... and 67 more
#
# 📄 Postgraduate_Program_in_Marketing_Intelligence.txt:
#    - Retrieved propositions: 62
#    - First propositions:
#      1. The Postgraduate Program in Marketing Intelligence aims to train experts and managers able to lead and guide the collection, compilation, analysis, and dissemination of marketing information in organizations.
#      2. The Postgraduate Program in Marketing Intelligence provides a balanced curriculum with two components.
#      3. One component of the curriculum is based on tools and methodologies of marketing management.
#      ... and 59 more
#
# 📄 Postgraduate_Program_in_Marketing_Research_and_CRM.txt:
#    - Retrieved propositions: 56
#    - First propositions:
#      1. The Postgraduate Program in Marketing Research and CRM fills a gap in the high-level training of managers, technical staff, and other marketing professionals.
#      2. The Postgraduate Program in Marketing Research and CRM highlights technical staff and market researchers.
#      3. The Postgraduate Program in Marketing Research and CRM highlights professionals involved in customer relationship management.
#      ... and 53 more
#
# 📄 Postgraduate_Program_in_Risk_Management.txt:
#    - Retrieved propositions: 63
#    - First propositions:
#      1. The Postgraduate program in Risk Management prepares professionals and executives to address challenges of identifying, assessing, and managing risk in the financial sector.
#      2. The program is aligned with leading international standards such as those set by the CFA Institute and GARP.
#      3. The program covers essential knowledge needed for informed decision-making.
#      ... and 60 more
#
# 📄 Postgraduate_Program_in_Statistical_Systems,_with_a_specialization_in_Central_Banks'_Statistics.txt:
#    - Retrieved propositions: 70
#    - First propositions:
#      1. The Postgraduate Program in Statistical Systems specializes in Central Bank Statistics.
#      2. The Postgraduate Program in Statistical Systems was developed in close collaboration with Banco de Portugal.
#      3. The program aims to provide managers and technical staff working in central bank statistics with fundamental knowledge and skills.
#      ... and 67 more
#
# 📄 Postgraduate_Program_in_Statistical_Systems,_with_a_specialization_in_Official_Statistics.txt:
#    - Retrieved propositions: 61
#    - First propositions:
#      1. The Postgraduate Program in Statistical Systems has a specialization in Official Statistics.
#      2. The Postgraduate Program in Statistical Systems is accredited by the European Statistical System (ESS) with the EMOS (European Master of Official Statistics) seal.
#      3. The Postgraduate Program offers specialized training in official statistics.
#      ... and 58 more
#
#  Total number of proposals retrieved: 2985

# %%
## ACCESS INDIVIDUAL PROPOSITIONS
def get_propositions_by_filename(filename):
    """
    Gets the propositions of a specific file
    """
    for doc in processed_documents:
        if doc['filename'] == filename:
            return doc['propositions']
    return None

# I tested to create chunks with all the documents but, some chunks were so huge that the RAG system could not handle them.

# %%
# Get propositions from a specific file
if processed_documents:
    first_filename = processed_documents[0]['filename']
    props = get_propositions_by_filename(first_filename)
    print(f"\nProposals from the file'{first_filename}':")
    for i, prop in enumerate(props[:3] if props else []):
        print(f"  {i+1}. {prop}")
# Out:
# Proposals from the file'03. NISS Registration.txt':
#   1. The Social Security Identification Number (NISS) allows unique, precise, and accurate identification of citizens in the Social Security system at the national level.
#   2. The Social Security Identification Number (NISS) is automatically allocated to national citizens when they apply for the Citizen Card.
#   3. Foreign citizens and national citizens who are not required to have a Citizen Card must submit a request for a Social Security Identification Number (NISS).

# %% [markdown]
# ### Start chunking process

# %%
# Check processed_documents
print(f"Total documents: {len(processed_documents)}")
# Out:
# Total documents: 50

# %%
# Show some general document statistics (number of prepositions)
prop_counts = [doc['num_propositions'] for doc in processed_documents]
print(f"Statistics of proposals by document:")
print(f"   • Average: {sum(prop_counts)/len(prop_counts):.1f}")
print(f"   • Min: {min(prop_counts)}")
print(f"   • Max: {max(prop_counts)}")
print(f"   • Total: {sum(prop_counts)}")
# Out:
# Statistics of proposals by document:
#    • Average: 59.7
#    • Min: 4
#    • Max: 108
#    • Total: 2985

# %% [markdown]
# #### Setup Agentic chunker

# %%
ac = AgenticChunker()

# %%
# Start the process to iterate per each document

results_by_document = {}

for doc in processed_documents:
    # Create a chunker for the document
    doc_chunker = create_agentic_chunker()

    # Add prepositions from the current document
    doc_chunker.add_propositions(doc['propositions'])

    # Chunks after the process
    chunks_after = ac.get_chunks()

    # Save results
    results_by_document[doc['filename']] = {
        # 'document_info': doc,
        'chunks': doc_chunker.get_chunks(get_type='list_of_strings'),
        'chunks_for_embedding': doc_chunker.get_chunks_for_embedding(),
        'stats': doc_chunker.get_stats()
    }

    print(f"{doc['filename']} was succesfully processed")
# Out:
# Adding: 'The Social Security Identification Number (NISS) allows unique, precise, and accurate identification of citizens in the Social Security system at the national level.'
# No chunks, creating a new one
# Created new chunk (3c13b): Identification Systems
#
# Adding: 'The Social Security Identification Number (NISS) is automatically allocated to national citizens when they apply for the Citizen Card.'
# Chunk Found (3c13b), adding to: Identification Systems
#
# Adding: 'Foreign citizens and national citizens who are not required to have a Citizen Card must submit a request for a Social Security Identification Number (NISS).'
# Chunk Found (3c13b), adding to: Social Security Identification Systems
#
# Adding: 'The request for a Social Security Identification Number (NISS) for these citizens is submitted via an online form called Pedido de NISS – Cidadão Estrangeiro ou Cidadão Nacional sem obrigatoriedade de ter cartão de cidadão.'
# Chunk Found (3c13b), adding to: Social Security Identification & Application
#
# Adding: 'The Social Security Identification Number (NISS) for legal persons is automatically allocated when companies are created online.'
# Chunk Found (3c13b), adding to: Social Security Identification & Processes
#
# Adding: 'Legal persons registered at commercial registry offices trigger electronic and free-of-charge communication to the Social Security Institute.'
# Chunk Found (3c13b), adding to: Social Security Identification System
#
# Adding: 'Legal persons' registration is mandatory and communicated to Social Security by the Tax and Customs Authority (AT).'
# Chunk Found (3c13b), adding to: Social Security Identification Number & Application Process
#
# Adding: 'Legal persons' registration is communicated to Social Security during activity beginning communication.'
# Chunk Found (3c13b), adding to: Social Security Identification Numbers & Registration Process
#
# Adding: 'Legal persons' registration is communicated to Social Security during the creation of companies or associations under certain schemes.'
# Chunk Found (3c13b), adding to: Social Security Identification Numbers & Allocation Process
#
# Adding: 'Legal persons' registration is communicated to Social Security during the admission of the first worker for natural persons employing others under employment contracts.'
# Chunk Found (3c13b), adding to: Social Security Identification Numbers & Registration Processes
#
# Adding: 'Legal persons' registration is communicated to Social Security during inspection activities when entities with workers are created without official registration.'
# Chunk Found (3c13b), adding to: Social Security Identification Numbers & Allocation Procedures
#
# Adding: 'Information on NISS allocation for legal persons is available in the Practical Guide – Registration and Change of Data – Legal Person.'
# Chunk Found (3c13b), adding to: Social Security Identification Numbers & Registration Processes
#
# Adding: 'National citizens with a Citizen Card automatically receive a Social Security Identification Number (NISS).'
# Chunk Found (3c13b), adding to: Social Security Identification Numbers & Procedures
#
# Adding: 'Foreign citizens and national citizens not required to have a Citizen Card must request a Social Security Identification Number (NISS) through the online form available on the Social Security Portal.'
# Chunk Found (3c13b), adding to: Social Security Identification Numbers & Registration
#
# Adding: 'Employers submitting applications for NISS allocation are exclusively doing so for foreign workers.'
# Chunk Found (3c13b), adding to: Social Security Identification Numbers & Procedures
#
# Adding: 'The Employer must communicate the worker's employment relationship through the Social Security Online Service (SSD – Segurança Social Direta).'
# Chunk Found (3c13b), adding to: Social Security Identification Numbers & Registration Processes
#
# Adding: 'Applicants themselves must submit necessary documents for NISS applications.'
# Chunk Found (3c13b), adding to: Social Security Identification Numbers & Allocation Processes
#
# Adding: 'National citizens without a Citizen Card must submit a valid ID card for the NISS application.'
# Chunk Found (3c13b), adding to: Social Security Registration & Allocation Procedures
#
# Adding: 'Foreign citizens from non-EU/EEA countries must submit copies of a Passport or Residence Permit (Temporary/Permanent) for the NISS application.'
# Chunk Found (3c13b), adding to: Social Security Identification Number (NISS) Processes
#
# Adding: 'Foreign citizens from EU/EEA countries or Switzerland must submit copies of a civil identification document, Passport, or Residence Card for the NISS application.'
# Chunk Found (3c13b), adding to: Social Security Identification Number (NISS) Allocation & Registration
#
# Adding: 'Citizens under International Protection must submit relevant proof of status for NISS applications.'
# Chunk Found (3c13b), adding to: Social Security Identification Number (NISS) Processes & Requirements
#
# Adding: 'The residence permit replaces the ID document for foreign citizens as per Article 84 of Law no. 23/2007.'
# Chunk Found (3c13b), adding to: Social Security Identification Number (NISS) Allocation & Registration Processes
#
# Adding: 'Documentary evidence required for NISS allocation includes employment contracts for employees or domestic service workers.'
# Chunk Found (3c13b), adding to: Social Security Identification Number (NISS) Procedures & Requirements
#
# Adding: 'Documentary evidence required for NISS allocation includes proof of self-employment activity and receipts/invoices for self-employed persons.'
# Chunk Found (3c13b), adding to: Social Security Identification Number (NISS) Processes & Guidelines
#
# Adding: 'Documentary evidence required for NISS allocation includes company registration certificates for Members of Statutory Bodies.'
# Chunk Found (3c13b), adding to: Social Security Identification Number (NISS) Allocation & Requirements
#
# Adding: 'Documentary evidence required for NISS allocation includes proof of an employment contract with a foreign Employer for Digital Nomads.'
# Chunk Found (3c13b), adding to: Social Security Identification Number (NISS) Processes & Documentation
#
# Adding: 'Documentary evidence required for NISS allocation includes proof of eligibility for Voluntary Social Insurance Scheme.'
# Chunk Found (3c13b), adding to: Social Security Identification Number (NISS) Allocation & Registration
#
# Adding: 'Foreign citizens from third countries must attach proof of residence permits or relevant visas to the NISS application form.'
# Chunk Found (3c13b), adding to: Social Security Identification Number (NISS) Processes & Requirements
#
# Adding: 'Relevant visas for foreign citizens include residence visas for subordinate professional activity, self-employed persons, teaching, research, cultural activities, remote work, and other purposes.'
# No chunks found
# Created new chunk (76d50): Immigration & Visas
#
# Adding: 'Members of Statutory Bodies residing outside Portugal must submit an ID document and proof of membership instead of residence permits.'
# Chunk Found (3c13b), adding to: Social Security Identification Number (NISS) Allocation & Documentation
#
# Adding: 'Foreign citizens from EU/EEA countries or Switzerland can attach residential register numbers or residence cards to the NISS application form.'
# Chunk Found (3c13b), adding to: Social Security Identification Number (NISS) Processes & Requirements
#
# Adding: 'Employers or legal representatives submitting NISS applications must submit proof of their ID and formal proof of legal representation.'
# Chunk Found (3c13b), adding to: Social Security Identification Number (NISS) Allocation & Documentation
#
# Adding: 'Employers or legal representatives submitting NISS applications may also submit Form PA-12 and an ID document instead of a power of attorney.'
# Chunk Found (3c13b), adding to: Social Security Identification Number (NISS) Procedures & Requirements
#
# Adding: 'Applicants must provide all identification data, including name, date of birth, gender, marital status, country of birth, place of birth, nationality, type and number of civil ID document, and more.'
# Chunk Found (3c13b), adding to: Social Security Identification Number (NISS) Guidelines
#
# Adding: 'Foreign citizens fulfilling certain conditions may request NISS, NIF, and NNU allocation in a single application.'
# Chunk Found (3c13b), adding to: Social Security Identification Number (NISS) Processes & Requirements
#
# Adding: 'Necessary conditions for the allocation of NISS, NIF, and NNU include holding or applying for a residence permit.'
# Chunk Found (3c13b), adding to: Social Security Identification Number (NISS) Allocation & Documentation
#
# Adding: 'Necessary conditions for the allocation of NISS, NIF, and NNU include being nationals of an EU country.'
# Chunk Found (3c13b), adding to: Social Security Identification Number (NISS) Allocation & Registration Processes
#
# Adding: 'Necessary conditions for the allocation of NISS, NIF, and NNU include applying for International Protection or having refugee status.'
# Chunk Found (3c13b), adding to: Social Security Identification Number (NISS) Allocation, Registration & Application Details
#
# Adding: 'The application for NISS, NIF, and NNU numbers can be submitted at specific Citizen Spaces in Portugal.'
# Chunk Found (3c13b), adding to: Social Security Identification Number (NISS) Procedures & Requirements
#
# Adding: 'Citizens submitting NISS, NIF, and NNU allocation requests must authenticate with Digital Mobile Key (CMD) or eIDAS.'
# Chunk Found (3c13b), adding to: Social Security Identification Numbers (NISS): Allocation, Applications & Documentation
#
# Adding: 'Foreign nationals submitting multiple NISS requests will receive only one NISS.'
# Chunk Found (3c13b), adding to: Identification Numbers & Related Applications
#
# Adding: 'Exceptional situations exist where foreign citizens cannot submit certain documents for NISS applications.'
# Chunk Found (3c13b), adding to: Social Security Identification Numbers (NISS) & Documentation
#
# Adding: 'AIMA, I.P. may request NISS allocation for foreign citizens to grant them residence permits for professional activities.'
# Chunk Found (3c13b), adding to: Social Security Identification Numbers (NISS) & Application Processes
#
# Adding: 'Foreign citizens in exceptional situations, such as those with job search visas, must attach a statement from AIMA, I.P. to the NISS application form.'
# Chunk Found (3c13b), adding to: Social Security Identification Numbers (NISS) & Eligibility Criteria
#
# Adding: 'EU regulations require attaching documents necessary for Social Security benefits to the NISS application form, regardless of nationality.'
# Chunk Found (3c13b), adding to: Social Security Identification Numbers (NISS) & Allocation Process
#
# Adding: 'A frontier worker must submit proof of employment or self-employment instead of a residence permit.'
# Chunk Found (76d50), adding to: Immigration & Visas
#
# Adding: 'The NISS document is collected by the person to whom it is allocated upon presenting a valid ID document.'
# Chunk Found (3c13b), adding to: Social Security Identification Numbers (NISS) & Application Guidelines
#
# Adding: 'The NISS document may be collected by a Lawyer with a professional certificate and power of attorney.'
# Chunk Found (3c13b), adding to: Social Security Identification Numbers (NISS) & Allocation Procedures
#
# Adding: 'A third party can collect the NISS document with an original power of attorney or Form PA-12 and the relevant ID document.'
# Chunk Found (3c13b), adding to: Social Security Identifiers & Application Guidelines
#
# Adding: 'The notification of NISS allocation is sent to the applicant's address or legal representative by Registered Letter.'
# Chunk Found (3c13b), adding to: Social Security Identifiers & Allocation Procedures
#
# Adding: 'Appointments to collect NISS documents can be scheduled through the Appointments Line on business days.'
# Chunk Found (3c13b), adding to: Social Security Identification Numbers & Application Details
#
# Adding: 'Additional details on NISS for foreign citizens and national citizens without Citizen Cards are available in the Practical Guide.'
# Chunk Found (3c13b), adding to: Social Security Identification & Application Processes
# 03. NISS Registration.txt was succesfully processed
#
# Adding: 'NOVA IMS offers 23 postgraduate programs.'
# No chunks, creating a new one
# Created new chunk (346df): Education Programs
#
# Adding: 'NOVA IMS offers 17 master's programs.'
# Chunk Found (346df), adding to: Education Programs
#
# Adding: 'NOVA IMS offers a Postgraduate Program in Artificial Intelligence for Business Transformation.'
# Chunk Found (346df), adding to: Academic Offerings
#
# Adding: 'NOVA IMS offers a Postgraduate Program in Business Intelligence.'
# Chunk Found (346df), adding to: Education Programs
#
# Adding: 'NOVA IMS offers a Postgraduate Program in Intelligence Management and Security.'
# Chunk Found (346df), adding to: Academic Offerings
#
# Adding: 'NOVA IMS offers a Postgraduate Program in Data Analytics.'
# Chunk Found (346df), adding to: Education Programs
#
# Adding: 'NOVA IMS offers a Postgraduate Program in Business Intelligence and Analytics for Hospitality & Tourism.'
# Chunk Found (346df), adding to: Academic Offerings
#
# Adding: 'NOVA IMS offers a Postgraduate Program Enterprise Data Science & Analytics.'
# Chunk Found (346df), adding to: Academic Programs & Specializations
#
# Adding: 'NOVA IMS offers a Postgraduate Program in Statistical Systems, with a specialization in Central Banks' Statistics.'
# Chunk Found (346df), adding to: Academic Offerings & Fields of Study
#
# Adding: 'NOVA IMS offers a Postgraduate Program in Statistical Systems, with a specialization in Official Statistics.'
# Chunk Found (346df), adding to: Academic Programs & Specializations
#
# Adding: 'NOVA IMS offers a Postgraduate Program in Data Science for Marketing.'
# Chunk Found (346df), adding to: Academic Offerings & Specializations
#
# Adding: 'NOVA IMS offers a Postgraduate Program in Digital Marketing and Analytics.'
# Chunk Found (346df), adding to: Educational Programs & Specializations
#
# Adding: 'NOVA IMS offers a Postgraduate Program in Marketing Intelligence.'
# Chunk Found (346df), adding to: Academic Programs & Offerings
#
# Adding: 'NOVA IMS offers a Postgraduate Program in Marketing Research and CRM.'
# Chunk Found (346df), adding to: Postgraduate & Master's Programs
#
# Adding: 'NOVA IMS offers a Postgraduate Program in Information Systems Management.'
# Chunk Found (346df), adding to: Academic Programs
#
# Adding: 'NOVA IMS offers a Postgraduate Program in Digital Transformation.'
# Chunk Found (346df), adding to: Postgraduate & Master's Academic Offerings
#
# Adding: 'NOVA IMS offers a Postgraduate Program in Data Science for Finance.'
# Chunk Found (346df), adding to: Graduate Academic Programs
#
# Adding: 'NOVA IMS offers a Postgraduate Program in Risk Management.'
# Chunk Found (346df), adding to: Postgraduate Academic Offerings
#
# Adding: 'NOVA IMS offers a Postgraduate Program in Financial and Budgetary Management and Control.'
# Chunk Found (346df), adding to: Academic Programs & Specializations
#
# Adding: 'NOVA IMS offers a Postgraduate Program in Financial Markets and Risks.'
# Chunk Found (346df), adding to: Postgraduate & Master's Programs
#
# Adding: 'NOVA IMS offers a Postgraduate Program in Geospatial Data Science.'
# Chunk Found (346df), adding to: Educational Programs & Specializations
#
# Adding: 'NOVA IMS offers a Postgraduate Program in Geographic Information Systems and Science.'
# Chunk Found (346df), adding to: Postgraduate & Master's Programs
#
# Adding: 'NOVA IMS offers a Postgraduate Program in Geospatial Intelligence.'
# Chunk Found (346df), adding to: Academic Programs
#
# Adding: 'NOVA IMS offers a Postgraduate Program in Information Management and Business Intelligence in Healthcare.'
# Chunk Found (346df), adding to: Postgraduate & Master's Programs
#
# Adding: 'NOVA IMS offers a Postgraduate Program in Health Data Science and Analytics.'
# Chunk Found (346df), adding to: Higher Education Programs
#
# Adding: 'NOVA IMS offers a Master Degree in Data Science and Advanced Analytics, with a specialization in Business Analytics.'
# Chunk Found (346df), adding to: Postgraduate and Master's Programs
#
# Adding: 'NOVA IMS offers a Master Degree in Information Management, with a specialization in Business Intelligence.'
# No chunks found
# Created new chunk (d2a41): Education Programs
#
# Adding: 'NOVA IMS offers a Master Degree in Data Science and Advanced Analytics, with a specialization in Data Science.'
# Chunk Found (346df), adding to: Educational Programs & Specializations
#
# Adding: 'NOVA IMS offers a Master Degree in Statistics and Information Management, with a specialization in Data Analytics.'
# Chunk Found (346df), adding to: Postgraduate & Master's Programs
#
# Adding: 'NOVA IMS offers a Master Degree in Data-Driven Marketing, with a specialization in Data Science for Marketing.'
# Chunk Found (346df), adding to: Academic Programs
#
# Adding: 'NOVA IMS offers a Master Degree in Data-Driven Marketing, with a specialization in Digital Marketing and Analytics.'
# Chunk Found (346df), adding to: Postgraduate & Master's Programs
#
# Adding: 'NOVA IMS offers a Master Degree in Data-Driven Marketing, with a specialization in Marketing Intelligence.'
# Chunk Found (346df), adding to: Education Programs
#
# Adding: 'NOVA IMS offers a Master Degree in Data-Driven Marketing, with a specialization in Marketing Research and CRM.'
# Chunk Found (346df), adding to: Postgraduate & Master's Programs
#
# Adding: 'NOVA IMS offers a European Master of Science in Information Systems Management.'
# Chunk Found (d2a41), adding to: Education Programs
#
# Adding: 'NOVA IMS offers a Master Degree in Information Management, with a specialization in Information Systems Management.'
# Chunk Found (d2a41), adding to: Information Management Education
#
# Adding: 'NOVA IMS offers a Master Degree in Information Management, with a specialization in Digital Transformation.'
# Chunk Found (346df), adding to: Higher Education Programs & Specializations
#
# Adding: 'NOVA IMS offers a Master Degree in Law and Financial Markets.'
# Chunk Found (346df), adding to: Postgraduate & Master's Program Specializations
#
# Adding: 'NOVA IMS offers a Master Degree in Risk Management.'
# Chunk Found (346df), adding to: Academic Program Offerings
#
# Adding: 'NOVA IMS offers a Master of Science in Geospatial Technologies.'
# Chunk Found (346df), adding to: Postgraduate & Master's Programs
#
# Adding: 'NOVA IMS offers a Master Degree in Geographic Information Systems and Science, with a specialization in Geospatial Data Science.'
# Chunk Found (346df), adding to: Academic Programs & Specializations
#
# Adding: 'NOVA IMS offers a Master Degree in Geographic Information Systems and Science, with a specialization in Geographic Information Systems and Science.'
# Chunk Found (346df), adding to: Postgraduate & Master's Programs
#
# Adding: 'NOVA IMS offers a Master Degree in Clinical Research Management.'
# Chunk Found (346df), adding to: Higher Education Programs
# 04. NOVA's master's programs.txt was succesfully processed
#
# Adding: 'NOVA IMS offers three bachelor's degree programs.'
# No chunks, creating a new one
# Created new chunk (0ead0): Academic Programs
#
# Adding: 'NOVA IMS offers a bachelor's degree program in Data Science.'
# Chunk Found (0ead0), adding to: Academic Programs
#
# Adding: 'NOVA IMS offers a bachelor's degree program in Information Management.'
# Chunk Found (0ead0), adding to: Higher Education Programs
#
# Adding: 'NOVA IMS offers a bachelor's degree program in Information Systems.'
# Chunk Found (0ead0), adding to: Degree Programs
# 05. NOVA's bachelor  programs.txt was succesfully processed
#
# Adding: 'Frequently asked questions can be explored to find answers.'
# No chunks, creating a new one
# Created new chunk (0ba67): FAQ Usage
#
# Adding: 'If you have unanswered questions, you can contact NOVA IMS.'
# No chunks found
# Created new chunk (efdd8): Support & Contact
#
# Adding: 'It is only possible to submit applications during the applications phase.'
# No chunks found
# Created new chunk (88e76): Applications & Deadlines
#
# Adding: 'The date of the call for applications is available on the Admissions and Fees page of each program.'
# Chunk Found (88e76), adding to: Applications & Deadlines
#
# Adding: 'You can fill the application form at any time and submit it when the applications phase starts.'
# Chunk Found (88e76), adding to: Admissions & Timelines
#
# Adding: 'Applications are submitted online in NOVA IMS’ Applications Portal.'
# Chunk Found (88e76), adding to: Application Process
#
# Adding: 'To submit an application, applicants must register in NOVA IMS’ Applications Portal.'
# Chunk Found (88e76), adding to: Applications & Timelines
#
# Adding: 'Applicants must fill the form in the Applications Portal.'
# Chunk Found (88e76), adding to: Application Process & Guidelines
#
# Adding: 'Applicants must upload their Curriculum Vitae in the Applications Portal.'
# Chunk Found (88e76), adding to: Admissions Process & Guidelines
#
# Adding: 'Applicants must choose the program in the Applications Portal.'
# Chunk Found (88e76), adding to: Application Submission Process
#
# Adding: 'Applicants must pay the application fee in the Applications Portal.'
# Chunk Found (88e76), adding to: Applications & Admissions Process
#
# Adding: 'The application process is the same for all applicants, national or international.'
# Chunk Found (88e76), adding to: Applications Process
#
# Adding: 'During the application process, the only mandatory document is the Curriculum Vitae (in .doc or .pdf format).'
# Chunk Found (88e76), adding to: Admissions & Application Process
#
# Adding: 'Applicants can upload other documents such as diplomas or certificates of their qualifications.'
# Chunk Found (88e76), adding to: Application Guidelines & Requirements
#
# Adding: 'Several websites can be used to convert files to PDF format.'
# No chunks found
# Created new chunk (85d75): File Conversion & Formatting Tools
#
# Adding: 'The websites for converting files to PDF format include: https://smallpdf.com/word-to-pdf, https://www.zamzar.com/, https://cloudconvert.com/, https://www.ilovepdf.com/, https://online2pdf.com/doc-to-pdf.'
# Chunk Found (85d75), adding to: File Conversion & Formatting Tools
#
# Adding: 'The application fee for the academic year 2025-26 is €51.'
# Chunk Found (88e76), adding to: Application Process Details
#
# Adding: 'The application fee is paid during the application process in NOVA IMS’ Applications Portal.'
# Chunk Found (88e76), adding to: Admissions Application Process
#
# Adding: 'Payment methods for the application fee include bank transfer or ATM reference, MBWay, PayPal, or Visa.'
# Chunk Found (88e76), adding to: Application Process
#
# Adding: 'Applications are considered successfully submitted only after the payment of the application fee within the stipulated time.'
# Chunk Found (88e76), adding to: Admissions & Application Process
#
# Adding: 'The application fee is non-refundable in case of withdrawal or non-admission to a program.'
# Chunk Found (88e76), adding to: Application Submission & Guidelines
#
# Adding: 'Applicants can apply to a maximum of 2 programs per application phase.'
# Chunk Found (88e76), adding to: Application Process & Requirements
#
# Adding: 'To apply to multiple programs, applicants must pay an application fee for each program.'
# Chunk Found (88e76), adding to: Admissions Application Process & Guidelines
#
# Adding: 'Applying to 1 program equals the payment of 1 application fee.'
# Chunk Found (88e76), adding to: Application Process & Requirements
#
# Adding: 'Applying to 2 programs equals the payment of 2 application fees.'
# Chunk Found (88e76), adding to: Applications & Admissions
#
# Adding: 'Final-year bachelor's degree students graduating by September 2025 are eligible to apply.'
# Chunk Found (88e76), adding to: Application Process
#
# Adding: 'Final-year bachelor's degree students must deliver an authenticated copy of their degree certificate or diploma by the beginning of the academic year in September 2025.'
# Chunk Found (88e76), adding to: Applications & Admissions
#
# Adding: 'The Tax Identification Number in Portugal is required to identify a taxable entity or person for tax declarations or financial transactions.'
# No chunks found
# Created new chunk (b4bb4): Tax Identification Requirements
#
# Adding: 'Applicants who do not have a Tax Identification Number should enter “999999999” in the application form field requesting it.'
# Chunk Found (b4bb4), adding to: Tax Identification Requirements
#
# Adding: 'In the application form field requesting 'Goals/motivation to apply to this program,' applicants should mention how their academic and professional background fits the program.'
# Chunk Found (88e76), adding to: Application Process
#
# Adding: 'Applicants should state their short-term professional goals in the field for 'Goals/motivation to apply to this program.''
# Chunk Found (88e76), adding to: Applications & Eligibility Criteria
#
# Adding: 'Applicants should specify their expectations from attending the program in the application form field 'Goals/motivation to apply to this program.''
# Chunk Found (88e76), adding to: Application Process & Submission Guidelines
#
# Adding: 'The selection process is based on the analysis of the academic and professional curriculum.'
# Chunk Found (88e76), adding to: Application Process & Requirements
#
# Adding: 'The Admissions Jury Panel may decide to hold interviews with all or some candidates.'
# Chunk Found (88e76), adding to: Admissions Application Process
#
# Adding: 'Interviews may be face-to-face or conducted via videoconference.'
# Chunk Found (88e76), adding to: Application Process & Requirements
#
# Adding: 'Interviews can be held at a distance using Zoom.'
# Chunk Found (88e76), adding to: Admissions Procedures & Criteria
#
# Adding: 'Application results are announced via email on a date specified in the confirmation of submitted application email or by the Admissions Jury or Programs Manager.'
# Chunk Found (88e76), adding to: Application Process & Requirements
#
# Adding: 'Admitted applicants must pay the pre-registration fee approximately one week after the results are announced.'
# Chunk Found (88e76), adding to: Applications & Admissions Process
#
# Adding: 'Admitted applicants must upload the diploma or certificate of their latest qualification after paying the pre-registration fee.'
# Chunk Found (88e76), adding to: Academic Application Process
#
# Adding: 'Examples of latest qualifications required for admitted applicants include Bachelor’s degree, Master’s degree, or PhD.'
# Chunk Found (88e76), adding to: Admissions & Application Process
#
# Adding: 'Applicants may attend two programs per academic year.'
# Chunk Found (88e76), adding to: Academic Admissions Process
#
# Adding: 'Attending two programs per academic year is not recommended due to possible overlaps in Mandatory Course Units and exams.'
# Chunk Found (88e76), adding to: Academic Applications & Admissions
#
# Adding: 'Admitted candidates to two programs must choose one program in the Applications Portal.'
# Chunk Found (88e76), adding to: Applications & Admissions Process
#
# Adding: 'Admitted candidates must pay the pre-registration fee for the chosen program.'
# Chunk Found (88e76), adding to: Academic Application & Enrollment Process
#
# Adding: 'Candidates admitted to two programs must select the 'Withdrawal' option for the program they do not intend to attend.'
# Chunk Found (88e76), adding to: Application Process & Admissions Guidelines
#
# Adding: 'By withdrawing from the second program, the vacancy becomes available to Waiting List candidates.'
# Chunk Found (88e76), adding to: Academic Application Process & Admissions
#
# Adding: 'Candidates on the Waiting List may still be admitted.'
# Chunk Found (88e76), adding to: Academic Application Guidelines & Procedures
#
# Adding: 'If a candidate admitted to two programs chooses to attend only one and there are remaining vacancies, Waiting List candidates may be assigned these vacancies.'
# Chunk Found (88e76), adding to: Academic Applications Process
#
# Adding: 'Invoices for application or pre-registration fees are available in NOVA IMS’ Applications Portal.'
# Chunk Found (88e76), adding to: Applications & Admissions
#
# Adding: 'The Invoice-Receipt is available within 2 business days after payment in the 'Billing/Treasury' tab of the Applications Portal.'
# Chunk Found (b4bb4), adding to: Tax & Financial Regulations
#
# Adding: 'NOVA IMS can issue a document proving program admission for visa purposes.'
# Chunk Found (88e76), adding to: Application Process & Guidelines
#
# Adding: 'The document proving program admission is sent to the student and the Embassy.'
# Chunk Found (88e76), adding to: Admissions & Application Procedures
#
# Adding: 'The admission document is issued only after payment of the pre-registration fee.'
# Chunk Found (88e76), adding to: Academic Application Process
#
# Adding: 'Students must contact the Portuguese Embassy or Consulate in their country for further information regarding visas.'
# Chunk Found (88e76), adding to: Application and Admission Process
#
# Adding: 'NOVA IMS does not award scholarships.'
# No chunks found
# Created new chunk (2a2b8): Financial Aid & Scholarships
#
# Adding: 'Applicants can apply for Universidade Nova de Lisboa scholarships and financial support provided by the university’s Social Welfare Services.'
# Chunk Found (2a2b8), adding to: Financial Aid & Scholarships
#
# Adding: 'Information about scholarships is available at https://sas.unl.pt/en/scholarships-2/scholarships_/.'
# Chunk Found (2a2b8), adding to: Financial Support & Scholarship Opportunities
#
# Adding: 'Applicants can contact bolsas@unl.pt for information about Universidade Nova de Lisboa scholarships.'
# Chunk Found (2a2b8), adding to: Scholarship & Financial Aid Information
#
# Adding: 'NOVA IMS does not hold information about other scholarships.'
# Chunk Found (2a2b8), adding to: Scholarships & Financial Support
#
# Adding: 'Students can park vehicles on campus if they have an access card.'
# No chunks found
# Created new chunk (89325): Campus Parking Policies
#
# Adding: 'Several parking areas are available on campus and near NOVA IMS.'
# Chunk Found (89325), adding to: Campus Parking Policies
#
# Adding: 'Requests for vehicle access to Campus de Campolide require registration or renewal of registration and payment.'
# Chunk Found (89325), adding to: Campus Parking & Accessibility
#
# Adding: 'Registration for vehicle access is completed in the system by selecting the type of access.'
# Chunk Found (89325), adding to: Campus Vehicle Access & Parking Policies
#
# Adding: 'Parking space management is the exclusive responsibility of the NOVA Rectory.'
# Chunk Found (89325), adding to: Campus Parking & Access Policies
#
# Adding: 'Information about Campus de Campolide parking is available at http://www.unl.pt/en/nova/parking-campus.'
# Chunk Found (89325), adding to: Campus Parking Policies & Management
#
# Adding: 'The Social Welfare Services of Universidade Nova have ties with three student residences.'
# No chunks found
# Created new chunk (664d0): Student Housing
#
# Adding: 'One of the student residences is located in Campus de Campolide.'
# Chunk Found (664d0), adding to: Student Housing
#
# Adding: 'Student residences provide accommodation for Portuguese scholarship students and international students.'
# Chunk Found (664d0), adding to: University-Affiliated Student Housing
#
# Adding: 'The capacity of student residences is limited.'
# Chunk Found (664d0), adding to: Student Housing & Support Services
#
# Adding: 'NOVA IMS cannot guarantee a room in the student residences.'
# Chunk Found (664d0), adding to: University-Affiliated Student Housing
#
# Adding: 'Applicants can be placed on the waiting list for residences only after confirmation of admission.'
# Chunk Found (664d0), adding to: Student Housing & Residency Options
#
# Adding: 'Information about student residences is available at https://sas.unl.pt/en/accommodation/.'
# Chunk Found (664d0), adding to: University-Linked Student Housing
#
# Adding: 'Admitted students seeking accommodation in university residences should contact adnovaims@novaims.unl.pt.'
# Chunk Found (664d0), adding to: Student Housing & Accommodation
#
# Adding: 'NOVA IMS provides a list of reference websites for accommodation.'
# Chunk Found (664d0), adding to: University Residences & Student Housing
#
# Adding: 'Accommodation websites in the reference list include: Airbnb, BQuarto, Casa Alfacinha, Collegiate, Coolivin, Easy Roommate, Erasmusu, Erasmus Life Lisboa, Erasmus Lisboa, Erasmus Student Network, Fundação Cidade de Lisboa, Housing Anywhere, Houze Student, Lemon Garden, Lisbon Rooms, Livensa Living, Residência Avenidas, Accommodation at Rua Fialho de Almeida 17 4E, Spot A Home, The Housing Concept, Traveling To Lisbon, UHub, Uniplaces, and Wimdu.'
# Chunk Found (664d0), adding to: Student Housing & Accommodation Resources
#
# Adding: 'The university offers a Portuguese course for international students.'
# No chunks found
# Created new chunk (d8b20): Education & Language Learning
#
# Adding: 'The Portuguese course is available in four types of classes: individual lessons, semester group lessons, 30-hour intensive course, and online summer course.'
# Chunk Found (d8b20), adding to: Education & Language Learning
#
# Adding: 'Individual lessons are scheduled based on the student's availability and arranged with the teacher.'
# Chunk Found (d8b20), adding to: Education & Courses
#
# Adding: 'The semester group lessons include 56 study classes and 8 hours for other activities.'
# No chunks found
# Created new chunk (3506d): Educational Structure
#
# Adding: 'The 30-hour intensive course is conducted over two weeks.'
# Chunk Found (d8b20), adding to: Language Education
#
# Adding: 'The online summer course takes place in July.'
# No chunks found
# Created new chunk (d3e52): Event & Course Scheduling
#
# Adding: 'Questions about the Portuguese course can be directed to cursoportugues@fcsh.unl.pt.'
# Chunk Found (d8b20), adding to: Education
# 06. NOVA's FAQ.txt was succesfully processed
#
# Adding: 'Law no. 23/2007, of July 4, approves the legal regime for the entry, stay, exit, and removal of foreigners from Portuguese national territory.'
# No chunks, creating a new one
# Created new chunk (c0f9c): Immigration Law
#
# Adding: 'Article 91 of Law no. 23/2007, in conjunction with Article 57 of Regulatory Decree no. 84/07 of November 5, establishes the framework for issuing residence permits to higher education students.'
# Chunk Found (c0f9c), adding to: Immigration Law
#
# Adding: 'A residence permit is granted to higher education students holding a residence visa issued under Article 62 of REPSAE.'
# Chunk Found (c0f9c), adding to: Immigration & Residence Regulations
#
# Adding: 'Higher education students must meet the general conditions of Article 77 of REPSAE to obtain a residence permit.'
# Chunk Found (c0f9c), adding to: Immigration & Residence Permits
#
# Adding: 'Higher education students must demonstrate that they meet admission requirements or have been accepted by a higher education institution to obtain a residence permit.'
# Chunk Found (c0f9c), adding to: Immigration Laws & Higher Education
#
# Adding: 'Higher education students must possess sufficient resources to attend a study program to obtain a residence permit.'
# Chunk Found (c0f9c), adding to: Immigration & Residence Permits for Higher Education
#
# Adding: 'A residence permit may be granted to a higher education student who does not hold a residence visa issued under Article 62 of REPSAE.'
# Chunk Found (c0f9c), adding to: Immigration & Residence Regulations for Study in Portugal
#
# Adding: 'Higher education students without a residence visa must have entered Portuguese national territory legally to obtain a residence permit.'
# Chunk Found (c0f9c), adding to: Immigration & Residence Permits for Higher Education in Portugal
#
# Adding: 'Higher education students without a residence visa must meet the conditions established in Article 91 of REPSAE to obtain a residence permit.'
# Chunk Found (c0f9c), adding to: Residence Permits for Higher Education Students in Portugal
#
# Adding: 'The application for a residence permit must be submitted by appointment or via an electronic platform in an implementation phase for residence visa holders.'
# Chunk Found (c0f9c), adding to: Immigration Policy for Higher Education Students in Portugal
#
# Adding: 'The application for a residence permit must be presented in person and accompanied by a specific form signed by the applicant or their legal representative.'
# Chunk Found (c0f9c), adding to: Residence Permits for Higher Education Students in Portugal
#
# Adding: 'The application for a residence permit can be submitted at any AIMA Service Center.'
# Chunk Found (c0f9c), adding to: Residence Permits & Legal Framework for Higher Education Students in Portugal
#
# Adding: 'AIMA Service Centers may forward residence permit applications, after processing and decision, to services in the applicant’s area of residence.'
# Chunk Found (c0f9c), adding to: Residence Permits & Procedures for Higher Education Students in Portugal
#
# Adding: 'The application for a residence permit must include two identical passport-style color photographs with a plain, updated background suitable for identification.'
# Chunk Found (c0f9c), adding to: Residence Permits & Legal Framework for Higher Education Students in Portugal
#
# Adding: 'Photographs are required only if applying at AIMA Service Centers in Odivelas or Aveiro.'
# Chunk Found (c0f9c), adding to: Residence Permits for Higher Education Students in Portugal
#
# Adding: 'The application for a residence permit must include a valid passport or other travel document.'
# Chunk Found (c0f9c), adding to: Residence Permits & Procedures for Higher Education Students in Portugal
#
# Adding: 'The application for a residence permit must include a valid residence visa issued under Article 62 of REPSAE, except in cases of applications without a visa under paragraph 4 of Article 91 of REPSAE.'
# Chunk Found (c0f9c), adding to: Legal Framework & Procedures for Residence Permits in Portugal
#
# Adding: 'The application for a residence permit must include a declaration under oath of residence address specifying the terms of residence.'
# Chunk Found (c0f9c), adding to: Residence Permits for Higher Education Students in Portugal
#
# Adding: 'Applicants residing as owners or usufructuaries must include a land registry certificate or access code to verify property or usufruct rights.'
# Chunk Found (c0f9c), adding to: Residence Permits & Procedures for Higher Education Students in Portugal
#
# Adding: 'Applicants residing as tenants or licensees must include a declaration from the landlord or hosting entity stating the legal basis for property use.'
# Chunk Found (c0f9c), adding to: Residence Permits & Legal Framework for Higher Education Students in Portugal
#
# Adding: 'The application for a residence permit must include proof of means of subsistence as required by Ordinance no. 1563/2007, of December 11.'
# Chunk Found (c0f9c), adding to: Residence Permits for Higher Education Students in Portugal
#
# Adding: 'The application for a residence permit must include a criminal record certificate from the applicant’s country of nationality.'
# Chunk Found (c0f9c), adding to: Residence Permits for Foreign Nationals in Portugal
#
# Adding: 'Applicants must provide a criminal record certificate from the country where they resided for more than one year before moving to Portugal.'
# Chunk Found (c0f9c), adding to: Residence Permits for Higher Education Students in Portugal
#
# Adding: 'Applicants must authenticate criminal record certificates as required by regulation.'
# Chunk Found (c0f9c), adding to: Residence Permits & Legal Framework for Foreigners in Portugal
#
# Adding: 'Applicants applying for a residence permit without a visa, under paragraph 4 of Article 91 of Law no. 23/2007, must provide proof of legal entry into Portuguese national territory.'
# Chunk Found (c0f9c), adding to: Residence Permits & Application Requirements in Portugal
#
# Adding: 'The application for a residence permit must include proof of enrollment at a higher education institution.'
# Chunk Found (c0f9c), adding to: Residence Permits & Legal Framework for Higher Education Students in Portugal
#
# Adding: 'The application for a residence permit must include proof of tuition fee payments required by the higher education institution, certified by a declaration if applicable.'
# Chunk Found (c0f9c), adding to: Residence Permits & Application Process for Higher Education Students in Portugal
#
# Adding: 'The application for a residence permit must include health insurance or proof of coverage by the National Health Service.'
# Chunk Found (c0f9c), adding to: Residence Permits & Legal Framework for Higher Education Students in Portugal
#
# Adding: 'Higher education students admitted under paragraph 5 of Article 91 of REPSAE are exempt from submitting proof of means of subsistence.'
# Chunk Found (c0f9c), adding to: Residence Permits & Requirements for Higher Education Students in Portugal
#
# Adding: 'Higher education students admitted under paragraph 5 of Article 91 of REPSAE are exempt from submitting proof of tuition payment.'
# Chunk Found (c0f9c), adding to: Residence Permits & Application Process for Higher Education Students in Portugal
#
# Adding: 'Higher education students receiving a scholarship from Instituto Camões are exempt from providing proof of enrollment.'
# Chunk Found (c0f9c), adding to: Residence Permits & Requirements for Higher Education Students in Portugal
#
# Adding: 'Higher education students receiving a scholarship from Instituto Camões are exempt from providing proof of tuition payment.'
# Chunk Found (c0f9c), adding to: Residence Permits for Higher Education Students in Portugal
#
# Adding: 'Higher education students receiving a scholarship from Instituto Camões are exempt from providing proof of health insurance.'
# Chunk Found (c0f9c), adding to: Residence Permits & Requirements for Students in Portugal
#
# Adding: 'Higher education students receiving a scholarship from Instituto Camões are exempt from providing proof of means of subsistence.'
# Chunk Found (c0f9c), adding to: Residence Permits & Legal Framework for Students in Portugal
#
# Adding: 'Granting a residence permit requires the absence of facts that would have prevented visa issuance if known to the authorities.'
# Chunk Found (c0f9c), adding to: Residence Permits & Requirements for Higher Education Students in Portugal
#
# Adding: 'Granting a residence permit requires the absence of convictions for crimes punishable in Portugal by imprisonment for more than one year.'
# Chunk Found (c0f9c), adding to: Residence Permits for Higher Education Students in Portugal
#
# Adding: 'Granting a residence permit requires the applicant not be subject to a ban on entry or stay in Portuguese national territory following a removal order.'
# Chunk Found (c0f9c), adding to: Residence Permit Framework & Process for Students in Portugal
#
# Adding: 'Granting a residence permit requires no alert in the Schengen Information System (SIS).'
# Chunk Found (c0f9c), adding to: Residence Permit Requirements & Procedures for Higher Education Students in Portugal
#
# Adding: 'Granting a residence permit requires no alert in the Foreigners’ Central Information Unit System (SII UCFE) for refusal of entry, stay, or re-entry under Articles 33 and 33-A.'
# Chunk Found (c0f9c), adding to: Residence Permits for Higher Education Students in Portugal
#
# Adding: 'The residence permit granted under Article 91 of REPSAE to higher education students is valid for three years.'
# Chunk Found (c0f9c), adding to: Residence Permits & Legal Framework for Higher Education Students in Portugal
#
# Adding: 'The residence permit granted under Article 91 of REPSAE to higher education students is renewable for equal periods.'
# Chunk Found (c0f9c), adding to: Residence Permits for Higher Education Students in Portugal
#
# Adding: 'If the study program duration is shorter than three years, the residence permit is issued for the duration of the program.'
# Chunk Found (c0f9c), adding to: Residency Regulations for Higher Education Students in Portugal
#
# Adding: 'The residence permit granted to students in EU or multilateral programs involving mobility measures is valid for two years or for the program duration, if shorter.'
# Chunk Found (c0f9c), adding to: Residence Permits for Higher Education Students in Portugal
#
# Adding: 'The residence permit granted to students under agreements between two or more higher education institutions is valid for two years or for the program duration, if shorter.'
# Chunk Found (c0f9c), adding to: Residence Permits for Students in Portugal
#
# Adding: 'The residence permit may be valid for one year if the conditions under paragraph 4 of Article 62 of REPSAE are not met at issuance.'
# Chunk Found (c0f9c), adding to: Residence Permits for Higher Education Students in Portugal
#
# Adding: 'Residence permit holders for study purposes may work in addition to the activity that justified their visa, as stipulated in Article 97 of REPSAE.'
# Chunk Found (c0f9c), adding to: Residence Permits for International Students in Portugal
#
# Adding: 'Directive (EU) 2016/801 of the European Parliament and Council of May 11, 2016, regulates entry and residence conditions for third-country nationals for research, studies, training, voluntary service, student exchange programs, educational projects, and au pair placements.'
# Chunk Found (c0f9c), adding to: Residence Permits for Higher Education Students in Portugal
# 07. AIMA Residence Permit Issued to Higher Education Students – Article 91.txt was succesfully processed
#
# Adding: 'Ordinance no. 1563/2007, of December 11, establishes the means of subsistence that third-country nationals must have for entry and stay in Portugal.'
# No chunks, creating a new one
# Created new chunk (b3de0): Immigration Laws
#
# Adding: 'The reference value for the means of subsistence is the guaranteed monthly minimum wage, that is, the national minimum wage.'
# Chunk Found (b3de0), adding to: Immigration Laws
#
# Adding: 'According to Decree-Law no. 107/2023, of November 17, the minimum wage set for 2024 is €820.'
# Chunk Found (b3de0), adding to: Legal & Financial Immigration Requirements
#
# Adding: 'Article 273 of the Labor Code specifies the national minimum wage set for 2024 as €820.'
# Chunk Found (b3de0), adding to: Immigration Regulations & Financial Standards
#
# Adding: 'To apply for family reunification, the applicant's household must have 100% of the minimum wage for the first adult.'
# Chunk Found (b3de0), adding to: Labor & Immigration Financial Standards
#
# Adding: 'To apply for family reunification, the applicant's household must have 50% of the minimum wage for the second or more adults.'
# Chunk Found (b3de0), adding to: Legal & Financial Requirements
#
# Adding: 'To apply for family reunification, the applicant's household must have 30% of the minimum wage for children under 18 years old.'
# Chunk Found (b3de0), adding to: Labor & Immigration Policies
#
# Adding: 'To apply for family reunification, the applicant's household must have 30% of the minimum wage for dependent adult children.'
# Chunk Found (b3de0), adding to: Legal & Financial Requirements in Portugal
#
# Adding: 'For the purposes of family reunification, the required amount of means of subsistence is calculated based on the specified percentages.'
# Chunk Found (b3de0), adding to: Legal & Financial Regulations in Portugal
#
# Adding: 'Proof of financial means depends on the applicant's situation.'
# Chunk Found (b3de0), adding to: National Minimum Wage & Immigration Policies in Portugal
#
# Adding: 'Proof of financial means may include a copy of a promise of employment contract or an employment contract.'
# Chunk Found (b3de0), adding to: Economic & Legal Framework for Immigration in Portugal
#
# Adding: 'Proof of financial means may include pay slips for the last three months.'
# Chunk Found (b3de0), adding to: Financial Regulations & Immigration Requirements in Portugal
#
# Adding: 'Proof of financial means may include a copy of a service provision contract or a promise of service provision contract.'
# Chunk Found (b3de0), adding to: Financial Rules & Residency Criteria in Portugal
#
# ...
#
# Adding: 'The Admissions’ Jury Panel values determination in applicants.'
# Chunk Found (d9f72), adding to: Admissions Criteria
#
# Adding: 'The Admissions’ Jury Panel values motivation in applicants’ academic and professional careers.'
# Chunk Found (d9f72), adding to: Admissions Process
#
# Adding: 'The application phase for the program runs from May 19th to June 18th, 2025.'
# No chunks found
# Created new chunk (70ac2): Date & Deadlines
#
# Adding: 'Applicants must hold a bachelor's degree in a compatible field completed by September 2025 to apply.'
# Chunk Found (d9f72), adding to: Applicant Selection Criteria
#
# Adding: 'Applicants must be proficient in English (spoken and written) to apply.'
# Chunk Found (d9f72), adding to: Admissions Process
#
# Adding: 'Applications must be submitted through NOVA IMS' Applications Portal.'
# Chunk Found (70ac2), adding to: Date & Deadlines
#
# Adding: 'Applicants must fill in a form detailing their personal, academic, and professional background.'
# Chunk Found (70ac2), adding to: Applications & Timelines
#
# Adding: 'Applicants must upload their Curriculum Vitae as a mandatory document.'
# Chunk Found (70ac2), adding to: Application Process
#
# Adding: 'Applicants can upload other documents to enrich their application, such as certificates of completion of degrees.'
# Chunk Found (70ac2), adding to: Application Requirements & Process
#
# Adding: 'Admitted applicants must submit a bachelor's and/or master's degree completion certificate within one month of admission.'
# Chunk Found (70ac2), adding to: Application Process & Guidelines
#
# Adding: 'Applicants must select the program of interest during application.'
# Chunk Found (70ac2), adding to: Application Process
#
# Adding: 'Applicants must present their goals and motivation for applying to the program in up to 1,000 characters including spaces.'
# Chunk Found (70ac2), adding to: Applications & Admissions
#
# Adding: 'Applicants must pay an application fee to complete their submission.'
# Chunk Found (70ac2), adding to: Application Process
#
# Adding: 'After submitting an application, applicants receive a confirmation email.'
# Chunk Found (70ac2), adding to: Program Application Requirements
#
# Adding: 'The selection process is based on the analysis of academic and professional curriculum.'
# Chunk Found (d9f72), adding to: Applicant Criteria
#
# Adding: 'The Admissions’ Jury Panel may hold interviews with all or some applicants.'
# Chunk Found (d9f72), adding to: Admissions Requirements
#
# Adding: 'Interviews may be conducted face-to-face or by videoconference.'
# Chunk Found (d9f72), adding to: Applicant Evaluation Criteria
#
# Adding: 'The application fee is €51.'
# Chunk Found (70ac2), adding to: Application Process
#
# Adding: 'The application fee is non-refundable in case of withdrawal or non-admission.'
# Chunk Found (70ac2), adding to: Program Application Details
#
# Adding: 'Admitted applicants must pay a pre-registration fee upon confirmation of enrollment.'
# Chunk Found (70ac2), adding to: Application Process Details
#
# Adding: 'The pre-registration fee is deductible from the tuition fee.'
# Chunk Found (70ac2), adding to: Program Application Process
#
# Adding: 'The pre-registration fee is non-refundable in case of withdrawal.'
# Chunk Found (70ac2), adding to: Admissions & Application Guidelines
#
# Adding: 'Applicants with nationality from EU member countries must pay a €1,250 pre-registration fee.'
# Chunk Found (70ac2), adding to: Program Application Process
#
# Adding: 'Applicants of other nationalities must pay a €2,500 pre-registration fee unless their registration fee is covered by an official entity.'
# Chunk Found (70ac2), adding to: Application Requirements & Process
#
# Adding: 'Upon registration, students must pay a €35 enrollment fee.'
# Chunk Found (70ac2), adding to: Program Application Details
#
# Adding: 'The enrollment fee is updated annually.'
# Chunk Found (70ac2), adding to: Program Application Process
#
# Adding: 'Upon registration, students must pay €1.40 for annual school insurance.'
# Chunk Found (70ac2), adding to: Application Guidelines and Fees
#
# Adding: 'The school insurance fee is updated annually.'
# No chunks found
# Created new chunk (7966f): Education & Insurance Policies
#
# Adding: 'The tuition fee for the Postgraduate Program is €4,900.'
# Chunk Found (7966f), adding to: Education & Insurance Policies
#
# Adding: 'The fee for each individual course unit in the program is €750.'
# Chunk Found (7966f), adding to: School Fees & Policies
#
# Adding: 'The full payment deadline for tuition is between September 25th and 30th, 2025.'
# Chunk Found (7966f), adding to: School Fees & Costs
#
# Adding: 'The tuition fee can be paid in four installments.'
# Chunk Found (7966f), adding to: School Fees, Costs & Deadlines
#
# Adding: 'The first installment of tuition (25%) is due between September 25th and 30th, 2025.'
# Chunk Found (7966f), adding to: Educational Financial Details
#
# Adding: 'The second installment of tuition (25%) is due between November 25th and 30th, 2025.'
# Chunk Found (7966f), adding to: Fees & Payment Information
#
# Adding: 'The third installment of tuition (25%) is due between February 22nd and 28th, 2026.'
# Chunk Found (7966f), adding to: Educational Costs & Payment Policies
#
# Adding: 'The fourth installment of tuition (25%) is due between April 25th and 30th, 2026.'
# Chunk Found (7966f), adding to: Fees & Payment Plans
#
# Adding: 'NOVA IMS programs combine theory with innovative teaching practices.'
# No chunks found
# Created new chunk (ba101): Education Programs & Methods
#
# Adding: 'Scholarship and award opportunities are available for NOVA IMS programs.'
# No chunks found
# Created new chunk (2fb66): Scholarships & Awards
#
# Adding: 'Details about scholarships and awards can be found at the relevant webpage.'
# Chunk Found (2fb66), adding to: Scholarships & Awards
# Postgraduate_Program_in_Statistical_Systems,_with_a_specialization_in_Central_Banks'_Statistics.txt was succesfully processed
#
# Adding: 'The Postgraduate Program in Statistical Systems has a specialization in Official Statistics.'
# No chunks, creating a new one
# Created new chunk (59b96): Academic Programs & Specializations
#
# Adding: 'The Postgraduate Program in Statistical Systems is accredited by the European Statistical System (ESS) with the EMOS (European Master of Official Statistics) seal.'
# Chunk Found (59b96), adding to: Academic Programs & Specializations
#
# Adding: 'The Postgraduate Program offers specialized training in official statistics.'
# Chunk Found (59b96), adding to: Academic Programs, Specializations & Accreditation
#
# Adding: 'The training focuses on the production of statistics covering the statistical activity of National Statistical Systems (NSS).'
# Chunk Found (59b96), adding to: Education & Accreditation
#
# Adding: 'The training covers statistical activities of international organizations of which Portugal is a member.'
# Chunk Found (59b96), adding to: Academic Programs in Official Statistics
#
# Adding: 'The program aims to provide knowledge and skills crucial to the exercise of activities related to NSS.'
# Chunk Found (59b96), adding to: Statistical Education & Accreditation
#
# Adding: 'The program targets technical staff and managers working in National Statistical Systems.'
# Chunk Found (59b96), adding to: Academic Programs in Statistical Systems
#
# Adding: 'These individuals may work as producers, analysts, or users of statistical information in National Statistical Systems.'
# Chunk Found (59b96), adding to: Postgraduate Training in Official Statistics
#
# Adding: 'The Postgraduate Program lasts for 2 semesters.'
# Chunk Found (59b96), adding to: Specialized Postgraduate Program in Official Statistics
#
# Adding: 'Students may attend the program in part-time mode.'
# Chunk Found (59b96), adding to: Postgraduate Training in Official Statistics
#
# Adding: 'Part-time students can complete the program within a stipulated period of 2 academic years.'
# Chunk Found (59b96), adding to: Specialized Education in Official Statistics
#
# Adding: 'The classes are held in the classroom or through videoconference.'
# Chunk Found (59b96), adding to: Postgraduate Program in Official Statistics
#
# Adding: 'Applications for the program are open between May 19th and June 18th, 2025.'
# Chunk Found (59b96), adding to: Statistical Training & Education
#
# Adding: 'The program manages and leads the process of producing official statistics.'
# Chunk Found (59b96), adding to: Postgraduate Program in Official Statistics
#
# Adding: 'The program develops techniques and methodologies for data collection.'
# Chunk Found (59b96), adding to: Educational Program in Statistical Systems
#
# Adding: 'The program teaches tools and processes used for the storage, organization, and access to information in entities responsible for compiling statistics.'
# Chunk Found (59b96), adding to: Postgraduate Program in Official Statistics
#
# Adding: 'The program applies statistical and computational methodologies to produce official statistics.'
# Chunk Found (59b96), adding to: Official Statistics Education
#
# Adding: 'The program includes the use of exploration and information analysis tools to support decision-making.'
# Chunk Found (59b96), adding to: Postgraduate Program in Official Statistics
#
# Adding: 'The program focuses on communicating results in written or oral form.'
# Chunk Found (59b96), adding to: Specialized Training in Official Statistics
#
# Adding: 'The communication of results is adapted to the level and specific interests of the audience.'
# Chunk Found (59b96), adding to: Postgraduate Program in Official Statistics
#
# Adding: 'Pedro Simões Coelho is the Program Coordinator of NOVA IMS' Postgraduate Program.'
# Chunk Found (59b96), adding to: Specialized Training in Official Statistics
#
# Adding: 'Pedro Simões Coelho holds the title of Full Professor.'
# No chunks found
# Created new chunk (7bdd3): Academic & Professional Roles
#
# Adding: 'Pedro Simões Coelho's email is psc@novaims.unl.pt.'
# Chunk Found (7bdd3), adding to: Academic & Professional Roles
#
# Adding: 'The program lasts 2 semesters starting in September 2025 and ending in June 2026.'
# Chunk Found (59b96), adding to: Postgraduate Program in Official Statistics
#
# Adding: 'Classes for the program occur after working hours (4:30 p.m.), 2 to 3 times a week.'
# Chunk Found (59b96), adding to: Postgraduate Program in Statistical Systems
#
# Adding: 'The NOVA IMS Admissions' Jury Panel seeks excellent students for the program.'
# No chunks found
# Created new chunk (f510a): Academic Admissions
#
# Adding: 'The Jury Panel looks for attributes such as maturity, determination, and motivation in the academic and professional paths of applicants.'
# Chunk Found (f510a), adding to: Academic Admissions
#
# Adding: 'The application phase is from May 19th to June 18th, 2025.'
# Chunk Found (59b96), adding to: Official Statistics Postgraduate Program
#
# Adding: 'Applicants must hold a bachelor's degree in a compatible field completed by September 2025.'
# Chunk Found (f510a), adding to: Applicant Qualities for Admissions
#
# Adding: 'Applicants must be proficient in English (spoken and written).'
# Chunk Found (f510a), adding to: Academic Admissions Criteria
#
# Adding: 'Applications can be made through NOVA IMS' Applications Portal.'
# Chunk Found (59b96), adding to: Postgraduate Program in Statistical Systems
#
# Adding: 'Applicants must fill in the application form with their personal, academic, and professional background.'
# Chunk Found (f510a), adding to: Admissions Requirements
#
# Adding: 'Applicants must upload their Curriculum Vitae.'
# Chunk Found (f510a), adding to: Eligibility Criteria
#
# Adding: 'The Curriculum Vitae is the only mandatory document for the application.'
# Chunk Found (f510a), adding to: Academic Program Admissions Requirements
#
# Adding: 'Applicants may optionally upload additional documents they consider relevant, such as certificates of their Bachelor's and/or Master's degree.'
# Chunk Found (f510a), adding to: Admissions Criteria & Application Requirements
#
# Adding: 'Admitted applicants must submit their Bachelor's and/or Master's degree completion certificate within one month of admission.'
# Chunk Found (f510a), adding to: Academic Program Admissions Details
#
# Adding: 'Applicants must choose the program on the application portal.'
# Chunk Found (f510a), adding to: Application Process & Requirements
#
# Adding: 'Applicants must present their goals and motivation for applying to the program within a 1,000-character limit.'
# Chunk Found (f510a), adding to: Admissions Criteria & Process
#
# Adding: 'Applicants must pay the application fee to finalize the application.'
# Chunk Found (f510a), adding to: Academic Program Admission Requirements & Process
#
# Adding: 'The application fee is €51.'
# Chunk Found (f510a), adding to: Admission Process & Criteria
#
# Adding: 'The application fee is non-refundable in case of withdrawal or non-admission to the program.'
# Chunk Found (f510a), adding to: Application Requirements & Criteria
#
# Adding: 'The selection process is based on an analysis of the applicant's academic and professional curriculum.'
# Chunk Found (f510a), adding to: Academic Program Application Process
#
# Adding: 'Members of the Admissions' Jury Panel may conduct interviews with applicants.'
# Chunk Found (f510a), adding to: Application & Admission Requirements
#
# Adding: 'Interviews can be held face-to-face or through videoconference.'
# Chunk Found (f510a), adding to: Academic Program Application Process
#
# Adding: 'Admitted applicants must pay a pre-registration fee upon confirmation of enrollment.'
# Chunk Found (f510a), adding to: Application Process & Requirements
#
# Adding: 'The pre-registration fee is deductible from the tuition fee.'
# Chunk Found (f510a), adding to: Admissions & Application Process
#
# Adding: 'The pre-registration fee is non-refundable in case of withdrawal.'
# Chunk Found (f510a), adding to: Academic Program Admissions Process
#
# Adding: 'The pre-registration fee for applicants from EU member countries is €1,250.'
# Chunk Found (f510a), adding to: Application & Selection Process
#
# Adding: 'The pre-registration fee for applicants from non-EU countries is €2,500 unless covered by an official entity.'
# Chunk Found (f510a), adding to: Admissions & Application Process
#
# Adding: 'Upon registration, students must pay an enrollment fee of €35.'
# Chunk Found (f510a), adding to: Application Process & Criteria
#
# Adding: 'The enrollment fee is updated annually.'
# Chunk Found (f510a), adding to: Admissions Requirements & Procedures
#
# Adding: 'Students must pay an annual school insurance fee of €1.40.'
# Chunk Found (f510a), adding to: Application, Selection, & Enrollment Process
#
# Adding: 'The school insurance fee is updated annually.'
# No chunks found
# Created new chunk (4e6e5): Education & Finances
#
# Adding: 'The tuition fee for the Postgraduate Program is €4,900.'
# Chunk Found (4e6e5), adding to: Education & Finances
#
# Adding: 'The tuition fee for each individual course unit is €750.'
# Chunk Found (4e6e5), adding to: Education Costs & Policies
#
# Adding: 'The tuition fee can be paid in full or in four installments.'
# Chunk Found (4e6e5), adding to: Education Costs
#
# Adding: 'Full tuition fee payment is due between September 25th and September 30th, 2025.'
# Chunk Found (4e6e5), adding to: School Fees & Payment Policies
#
# Adding: 'The first installment of the tuition fee (25%) is due between September 25th and September 30th, 2025.'
# Chunk Found (4e6e5), adding to: Education Costs & Payment Plans
#
# Adding: 'The second installment of the tuition fee (25%) is due between November 25th and November 30th, 2025.'
# Chunk Found (4e6e5), adding to: Education Financial Policies
#
# Adding: 'The third installment of the tuition fee (25%) is due between February 22nd and February 28th, 2026.'
# Chunk Found (4e6e5), adding to: School Financial Details
#
# Adding: 'The fourth installment of the tuition fee (25%) is due between April 25th and April 30th, 2026.'
# Chunk Found (4e6e5), adding to: Tuition Fees & Payment Policies
# Postgraduate_Program_in_Statistical_Systems,_with_a_specialization_in_Official_Statistics.txt was succesfully processed

# %% [markdown]
# ### Export and save results

# %%
def guardar_datos(datos: List[Dict[str, Any]], archivo: str = "datos.json"):
    """
    Saves the list of dictionaries in a JSON file
    
    Args:
        data: List of dictionaries with structure filename, original_content, propositions, num_propositions
        file: Name of the file to save (default: data.json)
    """
    try:
        with open(archivo, 'w', encoding='utf-8') as f:
            json.dump(datos, f, ensure_ascii=False, indent=2)
        print(f"Data successfully saved in {archivo}")
    except Exception as e:
        print(f"Error when saving: {e}")

# %%
# Let's store the "results_by_document" 
guardar_datos(results_by_document, os.path.join(ai_prepositions_path, "3-52_chunk_texts.json")) # change name if needed
# Out:
# Datos guardados exitosamente en 3-52_chunk_texts.json
